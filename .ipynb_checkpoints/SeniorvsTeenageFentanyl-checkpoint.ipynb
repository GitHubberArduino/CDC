# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sympy import *
import lmfit

# %%
def ratelessthan1(row):
        if row['rate'] < 1:
            return False
        else:
            return True

# %%
class DecayingSineModel(lmfit.Model):
    def __init__(self, *args, **kwargs):
        def decaying_sine(x,b,d):
            return pow(x,b)/(pow(x,b)+d)
        super(DecayingSineModel, self).__init__(decaying_sine, *args, **kwargs)

    def guess(self, data, **kwargs):
        params = self.make_params(b= 1.22, d= 3.33)
        return lmfit.models.update_param_vals(params, self.prefix, **kwargs)

# %%
def getModel(year):
    df = pd.read_csv(year)
    df["New"]= int('0')
    df.sort_values(by = ['rate'], ascending= [True])
    for county in df:
        df["New"] =  abs(df.index - 58)+1
    df2 = pd.DataFrame(columns=['rate', 'ccount'])
    for key in range(100):
        df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
    print(df2)
    model = DecayingSineModel()
    params = model.guess(df2['ccount'], x=df2['rate'])
    fit = model.fit(df2['ccount'], params, x=df2['rate'],nan_policy='omit')
    return fit, df2

# %%
f,df2= getModel('FentanylSeniors2016.csv')
# Out:
#     rate    ccount
# 0    0.0  0.000000
# 1    1.0  0.933333
# 2    2.0  0.933333
# 3    3.0  0.966667
# 4    4.0  0.966667
# ..   ...       ...
# 95  95.0  0.983333
# 96  96.0  0.983333
# 97  97.0  0.983333
# 98  98.0  0.983333
# 99  99.0  0.983333
#
# [100 rows x 2 columns]
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)

# %%
x = df2['rate']
y= df2['ccount']
plt.plot(x,y)

# %%
f.params["b"].value,f.params["d"].value
# Out:
# (0.3149316210424252, 0.05457872243689786)

# %%
f,df2= getModel('FentanylSeniors2016.csv')
# Out:
#     rate    ccount
# 0    0.0  0.000000
# 1    1.0  0.933333
# 2    2.0  0.933333
# 3    3.0  0.966667
# 4    4.0  0.966667
# ..   ...       ...
# 95  95.0  0.983333
# 96  96.0  0.983333
# 97  97.0  0.983333
# 98  98.0  0.983333
# 99  99.0  0.983333
#
# [100 rows x 2 columns]
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)

# %%
f.params["b"].value,f.params["d"].value
# Out:
# (0.3149316210424252, 0.05457872243689786)

# %%
df2
# Out:
#     rate    ccount
# 0    0.0  0.000000
# 1    1.0  0.933333
# 2    2.0  0.933333
# 3    3.0  0.966667
# 4    4.0  0.966667
# ..   ...       ...
# 95  95.0  0.983333
# 96  96.0  0.983333
# 97  97.0  0.983333
# 98  98.0  0.983333
# 99  99.0  0.983333
#
# [100 rows x 2 columns]

# %%
x = df2['rate']
y= df2['ccount']
plt.plot(x,y)

# %%
files = ['FentanylSeniors2021.csv','TeenagerFentanyl2021.csv','FentanylSeniors2020.csv','TeenagerFentanyl2020.csv','FentanylSeniors2019.csv','TeenagerFentanyl2019.csv',]
bval = []
dval = []
year = []
for file in files:
    f,df2 = getModel(file)
    year.append(file)
    bval.append(f.params["b"].value)
    dval.append(f.params["d"].value)
# Out:
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# ...
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/660294330.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)

# %%
bval
# Out:
# [1.0045582260974846,
#  1.3605628420509983,
#  0.9172894316958384,
#  1.2198860681008679,
#  0.6494910380711731,
#  0.9238075761038061]

# %%
year
# Out:
# ['FentanylSeniors2021.csv',
#  'TeenagerFentanyl2021.csv',
#  'FentanylSeniors2020.csv',
#  'TeenagerFentanyl2020.csv',
#  'FentanylSeniors2019.csv',
#  'TeenagerFentanyl2019.csv']

# %%
dval
# Out:
# [2.3501591877018106,
#  6.876571759781099,
#  1.005235976959877,
#  4.915454363468699,
#  0.2773789773902669,
#  0.8056957691840186]

# %%
year_no=0
density_x=[]
rate_y=[]
for x in range(60):
    b = bval[year_no]
    d = dval[year_no]
    q = pow(x,b)
    density_x.append(x)
    y_rate=d*b*pow(x,b-1)/(pow((q+d),2)) #derivativeofb&dequation
    rate_y.append(y_rate)

plt.plot(density_x,rate_y)

# %%
year_no=1
density_x=[]
rate_y=[]

for x in range(60):
    b = bval[year_no]
    d = dval[year_no]
    q = pow(x,b)
    density_x.append(x)
    y_rate=d*b*pow(x,b-1)/(pow((q+d),2))
    rate_y.append(y_rate)


plt.plot(density_x,rate_y)

# %%
x = [2021, 2020, 2019, 2018, 2017, 2016]
y = bval
plt.plot(x,y )

# %%
x = [2021,2020,2019,2018,2017,2016]
y = dval
plt.plot(x,y )

# %%
def prime3(x,b,d):
    q = pow(x,b)
    return (d*b*pow(x,b-1))/(pow((q+d),2))

# %%
bval_1 = bval[0:3]
bval_1
# Out:
# [1.0045582260974846, 1.3605628420509983, 0.9172894316958384]

# %%
bval_1 = bval[0:2]
bval_1 = dval[0:2]
year2= ["Senior","Teenager"]
for m in range(len(bval_1)):
    print(m)
    x = []
    y= []
    b = bval[m]
    d = dval[m]
    for i in range(100):
        x.append(i)
        y.append(prime3(x[i],b,d))
    plt.plot(x,y,label= str(year2[m]))
plt.legend(title='year')
plt.xlabel("Overdose Rates(Crude Rate for 100K)")
plt.ylabel("Probability based on number of counties")
plt.title("Density Curves: Seniors vs Teenagers 2021")
# Out:
# 0
# 1
# Text(0.5, 1.0, 'Density Curves: Seniors vs Teenagers 2021')

# %%
bval_2 = bval[0:4]
dval_2 = dval[0:4]
year2= ["Senior2021","Teenager2021", "Senior2020", "Teenager2020"]
for m in range(len(bval_2)):
    print(m)
    x = []
    y= []
    b = bval[m]
    d = dval[m]
    for i in range(100):
        x.append(i)
        y.append(prime3(x[i],b,d))
    plt.plot(x,y,label= str(year2[m]))
plt.legend(title='year')
plt.xlabel("Overdose Rates(Crude Rate for 100K)")
plt.ylabel("Probability based on number of counties")
plt.title("Density Curves: Seniors vs Teenagers 2020")
# Out:
# 0
# 1
# 2
# 3
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/1062718043.py:3: RuntimeWarning: divide by zero encountered in double_scalars
#   return (d*b*pow(x,b-1))/(pow((q+d),2))
# Text(0.5, 1.0, 'Density Curves: Seniors vs Teenagers 2020')

# %%
bval_3 = bval[2:4]
dval_3 = dval[2:4]
year2= ["Senior","Teenager"]
for m in range(len(bval_3)):
    print(m)
    x = []
    y= []
    b = bval_3[m]
    d = dval_3[m]
    for i in range(100):
        x.append(i)
        y.append(prime3(x[i],b,d))
    plt.plot(x,y,label= str(year2[m]))
plt.legend(title='year')
plt.xlabel("Overdose Rates(Crude Rate for 100K)")
plt.ylabel("Probability based on number of counties")
plt.title("Density Curves: Seniors vs Teenagers 2020")
# Out:
# 0
# 1
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/1062718043.py:3: RuntimeWarning: divide by zero encountered in double_scalars
#   return (d*b*pow(x,b-1))/(pow((q+d),2))
# Text(0.5, 1.0, 'Density Curves: Seniors vs Teenagers 2020')

# %%
bval_4 = bval[4:6]
dval_4 = dval[4:6]
year2= ["Senior","Teenager"]
for m in range(len(bval_3)):
    print(m)
    x = []
    y= []
    b = bval_4[m]
    d = dval_4[m]
    for i in range(100):
        x.append(i)
        y.append(prime3(x[i],b,d))
    plt.plot(x,y,label= str(year2[m]))
plt.legend(title='year')
plt.xlabel("Overdose Rates(Crude Rate for 100K)")
plt.ylabel("Probability based on number of counties")
plt.title("Density Curves: Seniors vs Teenagers 2019")
# Out:
# 0
# 1
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_90999/1062718043.py:3: RuntimeWarning: divide by zero encountered in double_scalars
#   return (d*b*pow(x,b-1))/(pow((q+d),2))
# Text(0.5, 1.0, 'Density Curves: Seniors vs Teenagers 2019')
