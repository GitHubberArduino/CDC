# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sympy import *

# %%
from lmfit.models import PolynomialModel

# %%
df = pd.read_csv('CrudeCounty2021.csv')

# %%
df["New"] = int('0')

# %%
df.sort_values(by = ['rate'], ascending= [True])
# Out:
#              county     rate     num1      num2      num3  New
# 58           Sierra   0.0000   0.0000  122.1100   0.00000    0
# 57             Mono   0.0000   0.0000   25.3100   0.00000    0
# 56           Colusa   0.0000   0.0000   16.9100   0.00000    0
# 55             Yolo   2.2400   0.9400    5.0575   0.83750    0
# 54         Monterey   6.1650   4.0775    8.9550   1.18000    0
# 53         Imperial   7.5750   4.1975   12.6650   1.99500    0
# 52      Santa Clara   7.9625   6.7550    9.3225   0.64000    0
# 51           Merced   8.3925   5.4425   12.4275   1.68000    0
# 50           Fresno   8.6425   6.9350   10.6475   0.92000    0
# 49         Siskiyou   9.2000   3.2400   22.9575   3.92500    0
# 48            Kings   9.5425   5.4350   15.6525   2.41500    0
# 47             Napa  10.2050   5.6500   17.0550   2.69000    0
# 46           Tulare  10.3150   7.7850   13.4950   1.40000    0
# 45           Plumas  10.4600   2.8500   36.4250   5.23000    0
# ...

# %%
for county in df:
    df["New"] =  abs(df.index - 58)+1

# %%
df
# Out:
#              county     rate     num1      num2      num3  New
# 0            Alpine  86.7300  23.6300  462.0200  43.36500   59
# 1         Mendocino  54.1750  39.8675   71.9750   7.87250   58
# 2     San Francisco  48.7125  44.2050   53.5500   2.35500   57
# 3              Lake  47.9075  32.7400   67.8125   8.50750   56
# 4           Trinity  40.8850  13.7425   95.0275  18.04500   55
# 5          Humboldt  32.7050  23.7750   43.8850   4.92250   54
# 6              Kern  29.3800  25.9875   33.1025   1.78500   53
# 7            Nevada  27.9825  18.6625   40.3800   5.25500   52
# 8             Butte  27.7850  21.3925   35.5300   3.48250   51
# 9              Inyo  27.4625  10.9825   62.4250  10.51750   50
# 10           Shasta  25.8900  19.2000   34.2575   3.69000   49
# 11          Ventura  25.4675  22.1900   29.1000   1.73250   48
# 12  San Luis Obispo  25.0375  19.5875   31.5575   2.95500   47
# 13           Sonoma  24.8025  20.6075   29.6075   2.24000   46
# ...

# %%
plt.plot(df['rate'],df['New']) 
plt.xlabel("Rate of Counties") 
plt.ylabel("Number of Counties")
# Out:
# Text(0, 0.5, 'Number of Counties')

# %% [markdown]
# plt.plot(df['rate'],df['New'])
# plt.xlabel("Rate of Counties")
# plt.ylabel("Number of Counties")

# %%
model3 = PolynomialModel()
params3 = model3.guess(df['New'], x = df['rate'])
result3 = model3.fit(df["New"], params3, nan_policy='omit', x = df['rate'])

# %%
result3.plot_fit()
# Out:
# <AxesSubplot:title={'center':'Model(polynomial)'}, xlabel='x', ylabel='y'>

# %%
params3
# Out:
# Parameters([('c0', <Parameter 'c0', value=2.6082779752733756, bounds=[-inf:inf]>), ('c1', <Parameter 'c1', value=-1.8986147470814208, bounds=[-inf:inf]>), ('c2', <Parameter 'c2', value=0.42611546707592296, bounds=[-inf:inf]>), ('c3', <Parameter 'c3', value=-0.01305627016379081, bounds=[-inf:inf]>), ('c4', <Parameter 'c4', value=-6.766784588965211e-05, bounds=[-inf:inf]>), ('c5', <Parameter 'c5', value=8.968246551313893e-06, bounds=[-inf:inf]>), ('c6', <Parameter 'c6', value=-1.4050807726031405e-07, bounds=[-inf:inf]>), ('c7', <Parameter 'c7', value=6.814382532119507e-10, bounds=[-inf:inf]>)])

# %%
polynomial = [0.00000000477008, -0.00000084306, 44841100,-0.00027062, - 0.03916881, 0.85223094, -1.89861475]

# %%
lower_limit = 0
upper_limit = 80
num_pts = 5000
x = np.linspace(lower_limit, upper_limit, num_pts)

# %%
poly_coefs = polynomial[::-1]
y = np.polyval(poly_coefs, x)

# %%
plt.plot(x, y)

# %%
x = Symbol('x')

# %%
y= 2.60827798 - 1.89861475*x + 0.42611547*(x**2) - 0.01305627*(x**3) - 6.7668e-5*(x**4) + 8.9682e-6*(x**5) - 1.4051e-7*(x**6) + 6.8144e-10*(x**7)

# %%
def asdf(row):
    row['checky'] = 2.60827798 - 1.89861475*row['rate'] + 0.42611547*(row['rate']**2) - 0.01305627*(row['rate']**3) - 6.7668e-5*(row['rate']**4) + 8.9682e-6*(row['rate']**5) - 1.4051e-7*(row['rate']**6) + 6.8144e-10*(row['rate']**7)
    return row['checky']

# %%
df['checky'] = df.apply(asdf,axis=1)

# %%
df
# Out:
#              county     rate     num1      num2      num3  New     checky
# 0            Alpine  86.7300  23.6300  462.0200  43.36500   59  58.009920
# 1         Mendocino  54.1750  39.8675   71.9750   7.87250   58  57.657839
# 2     San Francisco  48.7125  44.2050   53.5500   2.35500   57  57.050169
# 3              Lake  47.9075  32.7400   67.8125   8.50750   56  56.744260
# 4           Trinity  40.8850  13.7425   95.0275  18.04500   55  54.270896
# 5          Humboldt  32.7050  23.7750   43.8850   4.92250   54  53.035761
# 6              Kern  29.3800  25.9875   33.1025   1.78500   53  51.940404
# 7            Nevada  27.9825  18.6625   40.3800   5.25500   52  51.136394
# 8             Butte  27.7850  21.3925   35.5300   3.48250   51  51.001885
# 9              Inyo  27.4625  10.9825   62.4250  10.51750   50  50.770266
# 10           Shasta  25.8900  19.2000   34.2575   3.69000   49  49.412757
# 11          Ventura  25.4675  22.1900   29.1000   1.73250   48  48.979076
# ...

# %%
yprime = y.diff(x)

# %%
yprime
# Out:
# 4.77008e-9*x**6 - 8.4306e-7*x**5 + 4.4841e-5*x**4 - 0.000270672*x**3 - 0.03916881*x**2 + 0.85223094*x - 1.89861475

# %%
def asdf(row):
    x == row['rate']
    row['checky'] = yprime
    return row['checky']

# %%
originalCoefs = [params3["c0"].value,params3["c1"].value,params3["c2"].value,params3["c3"].value,params3["c4"].value,params3["c5"].value,params3["c6"].value,params3["c7"].value]

# %%
originalCoefs
# Out:
# [2.6082779752733756,
#  -1.8986147470814208,
#  0.42611546707592296,
#  -0.01305627016379081,
#  -6.766784588965211e-05,
#  8.968246551313893e-06,
#  -1.4050807726031405e-07,
#  6.814382532119507e-10]

# %%
diffCoefs = [originalCoefs[1],2*originalCoefs[2],3*originalCoefs[3],4*originalCoefs[4],5*originalCoefs[5],6*originalCoefs[6],7*originalCoefs[7]]

# %%
def prime(row):
    r = diffCoefs[0] + diffCoefs[1] * row['rate']  + diffCoefs[2] * (row['rate']**2) + diffCoefs[3] * (row['rate']**3) + diffCoefs[4] * (row['rate']**4) + diffCoefs[5] * (row['rate']**5) + diffCoefs[6] * (row['rate']**6)
    return r

# %%
df['yprime'] = df.apply(prime,axis=1)

# %%
df
# Out:
#              county     rate     num1      num2      num3  New     checky  \
# 0            Alpine  86.7300  23.6300  462.0200  43.36500   59  58.009920
# 1         Mendocino  54.1750  39.8675   71.9750   7.87250   58  57.657839
# 2     San Francisco  48.7125  44.2050   53.5500   2.35500   57  57.050169
# 3              Lake  47.9075  32.7400   67.8125   8.50750   56  56.744260
# 4           Trinity  40.8850  13.7425   95.0275  18.04500   55  54.270896
# 5          Humboldt  32.7050  23.7750   43.8850   4.92250   54  53.035761
# 6              Kern  29.3800  25.9875   33.1025   1.78500   53  51.940404
# 7            Nevada  27.9825  18.6625   40.3800   5.25500   52  51.136394
# 8             Butte  27.7850  21.3925   35.5300   3.48250   51  51.001885
# 9              Inyo  27.4625  10.9825   62.4250  10.51750   50  50.770266
# 10           Shasta  25.8900  19.2000   34.2575   3.69000   49  49.412757
# 11          Ventura  25.4675  22.1900   29.1000   1.73250   48  48.979076
# ...

# %%
df_filter = df[df['rate']<55]

# %%
plt.plot(df_filter['rate'], df_filter['yprime'])

# %%
result3.plot_fit()
# Out:
# <AxesSubplot:title={'center':'Model(polynomial)'}, xlabel='x', ylabel='y'>

# %%
def ratelessthan1(row):
    if row['rate'] < 1:
        return False
    else:
        return True

# %%
len(df[df['rate']<10])
# Out:
# 11

# %%
df2 = pd.DataFrame(columns=['rate', 'ccount'])

for key in range(100):
    df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# Out:
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_31048/3379024307.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_31048/3379024307.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_31048/3379024307.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# ...

# %%
df2
# Out:
#     rate    ccount
# 0    0.0  0.000000
# 1    1.0  0.050000
# 2    2.0  0.050000
# 3    3.0  0.066667
# 4    4.0  0.066667
# ..   ...       ...
# 95  95.0  0.983333
# 96  96.0  0.983333
# 97  97.0  0.983333
# 98  98.0  0.983333
# 99  99.0  0.983333
#
# [100 rows x 2 columns]

# %%
df2
# Out:
#     rate    ccount
# 0    0.0  0.000000
# 1    1.0  0.050000
# 2    2.0  0.050000
# 3    3.0  0.066667
# 4    4.0  0.066667
# ..   ...       ...
# 95  95.0  0.983333
# 96  96.0  0.983333
# 97  97.0  0.983333
# 98  98.0  0.983333
# 99  99.0  0.983333
#
# [100 rows x 2 columns]

# %%
plt.plot(df2['rate'],df2['ccount']) 
plt.xlabel("Rate of Counties") 
plt.ylabel("Cumulative Percentage of Counties")
# Out:
# Text(0, 0.5, 'Cumulative Percentage of Counties')

# %%
model4 = PolynomialModel(7)
params4 = model4.guess(df2['ccount'], x = df2['rate'])
result4 = model4.fit(df2["ccount"], params4, nan_policy='omit', x = df2['rate'])

# %%
df2
# Out:
#     rate    ccount
# 0    0.0  0.000000
# 1    1.0  0.050000
# 2    2.0  0.050000
# 3    3.0  0.066667
# 4    4.0  0.066667
# ..   ...       ...
# 95  95.0  0.983333
# 96  96.0  0.983333
# 97  97.0  0.983333
# 98  98.0  0.983333
# 99  99.0  0.983333
#
# [100 rows x 2 columns]

# %%
result4
# Out:
# <h2> Model</h2> Model(polynomial) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>9</td><td></td></tr><tr><td># data points</td><td>100</td><td></td></tr><tr><td># variables</td><td>8</td><td></td></tr><tr><td>chi-square</td><td> 0.02801397</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.0450e-04</td><td></td></tr><tr><td>Akaike info crit.</td><td>-802.022231</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-781.180870</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> c0 </td><td>  0.06722890 </td><td>  0.01202350 </td><td> (17.88%) </td><td> 0.0672289039341292 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> c1 </td><td> -0.04163243 </td><td>  0.00457113 </td><td> (10.98%) </td><td> -0.04163243179331507 </t
# ...

# %%
result4.plot_fit()
# Out:
# <AxesSubplot:title={'center':'Model(polynomial)'}, xlabel='x', ylabel='y'>

# %%
params4
# Out:
# Parameters([('c0', <Parameter 'c0', value=0.0672289039341292, bounds=[-inf:inf]>), ('c1', <Parameter 'c1', value=-0.04163243179331507, bounds=[-inf:inf]>), ('c2', <Parameter 'c2', value=0.009585713493280287, bounds=[-inf:inf]>), ('c3', <Parameter 'c3', value=-0.00047839016536230667, bounds=[-inf:inf]>), ('c4', <Parameter 'c4', value=1.1343973879281709e-05, bounds=[-inf:inf]>), ('c5', <Parameter 'c5', value=-1.4277475148525096e-07, bounds=[-inf:inf]>), ('c6', <Parameter 'c6', value=9.194758900289026e-10, bounds=[-inf:inf]>), ('c7', <Parameter 'c7', value=-2.3853950932426238e-12, bounds=[-inf:inf]>)])

# %%
paramsline = []
for key in range(8):
    paramsline.append(params4["c" + str(key)].value)

# %%
derivline = []
for key in range(7):
    derivline.append((key+1)*(paramsline[key+1]))

# %%
derivline
# Out:
# [-0.04163243179331507,
#  0.019171426986560575,
#  -0.00143517049608692,
#  4.5375895517126835e-05,
#  -7.138737574262548e-07,
#  5.516855340173415e-09,
#  -1.6697765652698366e-11]

# %%
def prime2(row):
    dsum = 0
    for key in range(7):
        dsum = dsum + derivline[key] * pow(row['rate'], key)
    return dsum

# %%
df2['yprime'] = df2.apply(prime2,axis=1)

# %%
df2_filter = df2[df2['rate']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [280], in <cell line: 1>()
# ----> 1 df2_filter = df2[df2['rate']]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
df2_filter
# Out:
#     rate    ccount    yprime
# 5    5.0  0.066667  0.023588
# 6    6.0  0.066667  0.030648
# 7    7.0  0.083333  0.036185
# 8    8.0  0.116667  0.040373
# 9    9.0  0.150000  0.043374
# ..   ...       ...       ...
# 95  95.0  0.983333 -0.000083
# 96  96.0  0.983333 -0.002014
# 97  97.0  0.983333 -0.004556
# 98  98.0  0.983333 -0.007808
# 99  99.0  0.983333 -0.011879
#
# [95 rows x 3 columns]

# %%
plt.bar(df2_filter['rate'], df2_filter['yprime'])
# Out:
# <BarContainer object of 95 artists>

# %%
df2_filter['rate']
# Out:
# 5      0.0
# 6      1.0
# 7      2.0
# 8      3.0
# 9      4.0
#       ...
# 95    90.0
# 96    91.0
# 97    92.0
# 98    93.0
# 99    94.0
# Name: rate, Length: 95, dtype: float64

# %%
 plt.plot(df2_filter['rate'], df2_filter['yprime'])
plt.xlabel("Rate of Counties") 
plt.ylabel("Rate of Change in Percentage of Counties")
# Out:
# Text(0, 0.5, 'Rate of Change in Percentage of Counties')

# %% [markdown]
# ###

# %%
import lmfit

model = lmfit.models.ExpressionModel("x^b/(x^b+d)")

# %%
params = model.make_params(b=1.222, d=3.333)
fit = model.fit(df2_filter['ccount'], params, x= df2_filter['rate'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/asteval/asteval.py:301, in Interpreter.run(self, node, expr, lineno, with_raise)
#     300 try:
# --> 301     ret = handler(node)
#     302     if isinstance(ret, enumerate):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/asteval/asteval.py:584, in Interpreter.on_binop(self, node)
#     583 """Binary operator."""
# --> 584 return op2func(node.op)(self.run(node.left),
#     585                         self.run(node.right))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/asteval/astutils.py:232, in <lambda>(a, b)
#     222     return a << b
#     225 OPERATORS = {ast.Is: lambda a, b: a is b,
#     226              ast.IsNot: lambda a, b: a is not b,
# ...

# %%
df2_filter
# Out:
#     rate    ccount    yprime
# 5    5.0  0.066667  0.023588
# 6    6.0  0.066667  0.030648
# 7    7.0  0.083333  0.036185
# 8    8.0  0.116667  0.040373
# 9    9.0  0.150000  0.043374
# ..   ...       ...       ...
# 95  95.0  0.983333 -0.000083
# 96  96.0  0.983333 -0.002014
# 97  97.0  0.983333 -0.004556
# 98  98.0  0.983333 -0.007808
# 99  99.0  0.983333 -0.011879
#
# [95 rows x 3 columns]

# %%
class DecayingSineModel(lmfit.Model):
    def __init__(self, *args, **kwargs):
        def decaying_sine(x,b,d):
            return pow(x,b)/(pow(x,b)+d)
        super(DecayingSineModel, self).__init__(decaying_sine, *args, **kwargs)

    def guess(self, data, **kwargs):
        params = self.make_params(b=1.22, d= 3.33)
        return lmfit.models.update_param_vals(params, self.prefix, **kwargs)

# %%
model = DecayingSineModel()
params = model.guess(df2_filter['ccount'], x=df2_filter['rate'])
fit = model.fit(df2_filter['ccount'], params, x=df2_filter['rate'])

# %%
fit.plot_fit()
# Out:
# <AxesSubplot:title={'center':'Model(decaying_sine)'}, xlabel='x', ylabel='y'>

# %%
fit
# Out:
# <h2> Model</h2> Model(decaying_sine) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>59</td><td></td></tr><tr><td># data points</td><td>95</td><td></td></tr><tr><td># variables</td><td>2</td><td></td></tr><tr><td>chi-square</td><td> 0.03263347</td><td></td></tr><tr><td>reduced chi-square</td><td> 3.5090e-04</td><td></td></tr><tr><td>Akaike info crit.</td><td>-753.747911</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-748.640157</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> b </td><td>  2.68586255 </td><td>  0.04228751 </td><td> (1.57%) </td><td> 1.22 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> d </td><td>  1650.10151 </td><td>  207.320209 </td><td> (12.56%) </td><td> 3.33 </td><td>        -inf </td><td>  
# ...

# %%
b = 2.68586255
d = 1650.10151

# %%
def prime3(row):
    x = row['rate']
    q = pow(x,b)
    return (d*b*pow(x,b-1))/(pow((q+d),2))

# %%
df2['derivative'] = df2.apply(prime3,axis=1)

# %%
df2
# Out:
#     rate    ccount    yprime  derivative
# 0    0.0  0.000000 -0.041632    0.000000
# 1    1.0  0.050000 -0.023852    0.001626
# 2    2.0  0.050000 -0.008678    0.005196
# 3    3.0  0.066667  0.004134    0.010137
# 4    4.0  0.066667  0.014817    0.016034
# ..   ...       ...       ...         ...
# 95  95.0  0.983333 -0.000083    0.000224
# 96  96.0  0.983333 -0.002014    0.000215
# 97  97.0  0.983333 -0.004556    0.000208
# 98  98.0  0.983333 -0.007808    0.000200
# 99  99.0  0.983333 -0.011879    0.000193
#
# [100 rows x 4 columns]

# %%
plt.bar(df2['rate'],df2['derivative'] )
# Out:
# <BarContainer object of 100 artists>

# %%
df2
# Out:
#     rate    ccount    yprime  derivative
# 5    5.0  0.066667  0.023588    0.022446
# 6    6.0  0.066667  0.030648    0.028905
# 7    7.0  0.083333  0.036185    0.034951
# 8    8.0  0.116667  0.040373    0.040184
# 9    9.0  0.150000  0.043374    0.044308
# ..   ...       ...       ...         ...
# 95  95.0  0.983333 -0.000083    0.000224
# 96  96.0  0.983333 -0.002014    0.000215
# 97  97.0  0.983333 -0.004556    0.000208
# 98  98.0  0.983333 -0.007808    0.000200
# 99  99.0  0.983333 -0.011879    0.000193
#
# [95 rows x 4 columns]
