# %%
import pandas as pd

# numpy is a standard module for simple numerical calculations
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams["figure.figsize"] = (20,15)

# %%
df1 = pd.read_csv("indexgini.csv")
df1['Data'] = pd.to_numeric(df1['Data'], errors='coerce')
df1['Data'] = df1["Data"].astype(float)

# %%
df2 = pd.read_csv("teenagerfentanyl2021.csv")
df2["Location"] = df2["county"] + " County"

# %%
dfmerge = pd.merge(df1, df2, on = "Location")

# %%
x = dfmerge["Data"]
y = dfmerge["rate"]
plt.scatter(x,y)
plt.title(" Scatterplot: Teenager Gini Index vs Fentanyl Overdose 2021")
plt.xlabel("Gini Index")
plt.ylabel("Crude Rate")
# Out:
# Text(0, 0.5, 'Crude Rate')

# %%
df3 = pd.read_csv("TeenagerFentanyl2021.csv")
df3["Location"] = df3["county"] + " County"

# %%
dfmerge2 = pd.merge(df1, df3, on = "Location")

# %%
x = dfmerge2["Data"]
y = dfmerge2["rate"]
plt.scatter(x,y)
plt.title("Gini Index vs All Opioid and Meth Crude Rate 2021")
plt.xlabel("Gini Index")
plt.ylabel("Crude Rate")
# Out:
# Text(0, 0.5, 'Crude Rate')

# %%
import pandas as pd

data = {
    'Year': ['2018', '2019', '2020', '2021'],
    'Year Code': ['2018', '2019', '2020', '2021'],
    'Deaths': [57, 91, 252, 228],
    'Population': [2043504, 2029982, 2009611, 2048741],
    'Crude Rate': [2.8, 4.5, 12.5, 11.1]
}

dfrate = pd.DataFrame(data)
print(dfrate)
# Out:
#    Year Year Code  Deaths  Population  Crude Rate
# 0  2018      2018      57     2043504         2.8
# 1  2019      2019      91     2029982         4.5
# 2  2020      2020     252     2009611        12.5
# 3  2021      2021     228     2048741        11.1

# %%
data7 = {
    'Year': ['2013', '2014', '2015', '2016', '2017'],
    'Year Code': ['2013', '2014', '2015', '2016', '2017'],
    'Deaths': [38, 36, 38, 38, 30],
    'Population': [2143455, 2111502, 2083996, 2069462, 2065794],
    'Crude Rate': [1.8, 1.7, 1.8, 1.8, 1.5]
}

dfrate7 = pd.DataFrame(data7)

# %%
combined_dfca = pd.concat([dfrate7, dfrate], ignore_index=True)

# %%
combined_dfca
# Out:
#    Year Year Code  Deaths  Population  Crude Rate
# 0  2013      2013      38     2143455         1.8
# 1  2014      2014      36     2111502         1.7
# 2  2015      2015      38     2083996         1.8
# 3  2016      2016      38     2069462         1.8
# 4  2017      2017      30     2065794         1.5
# 5  2018      2018      57     2043504         2.8
# 6  2019      2019      91     2029982         4.5
# 7  2020      2020     252     2009611        12.5
# 8  2021      2021     228     2048741        11.1

# %%
ratenotworking = [8.2, 7.3, 6.7, 6.5, 6.8, 6.5, 6.1, 7, 7]

# %%
x2 = ratenotworking
x3=combined_dfca["Crude Rate"]
y = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
plt.plot(y, x2)
plt.plot(y, x3)
plt.title("Year vs. Crude Rate and Rate of Ages 16-19 not working or not in school")
plt.xlabel("Year")
plt.ylabel("Percentage")
plt.legend(["Not working", "Crude Rate for All Drugs "])

# %%
import pandas as pd

data = {
    "County": [
        "Alameda County, CA",
        "Butte County, CA",
        "Contra Costa County, CA",
        "El Dorado County, CA",
        "Fresno County, CA",
        "Humboldt County, CA",
        "Imperial County, CA",
        "Kern County, CA",
        "Kings County, CA",
        "Lake County, CA",
        "Los Angeles County, CA",
        "Madera County, CA",
        "Marin County, CA",
        "Mendocino County, CA",
        "Merced County, CA",
        "Monterey County, CA",
        "Napa County, CA",
        "Nevada County, CA",
        "Orange County, CA",
        "Placer County, CA",
        "Riverside County, CA",
        "Sacramento County, CA",
        "San Bernardino County, CA",
        "San Diego County, CA",
        "San Francisco County, CA",
        "San Joaquin County, CA",
        "San Luis Obispo County, CA",
        "San Mateo County, CA",
        "Santa Barbara County, CA",
        "Santa Clara County, CA",
        "Santa Cruz County, CA",
        "Shasta County, CA",
        "Solano County, CA",
        "Sonoma County, CA",
        "Stanislaus County, CA",
        "Sutter County, CA",
        "Tulare County, CA",
        "Ventura County, CA",
        "Yuba County, CA"
    ],
    "County Code": [
        "06001", "06007", "06013", "06017", "06019", "06023", "06025", "06029", "06031", "06033", "06037",
        "06039", "06041", "06045", "06047", "06053", "06055", "06057", "06059", "06061", "06065", "06067",
        "06071", "06073", "06075", "06077", "06079", "06081", "06083", "06085", "06087", "06089", "06095",
        "06097", "06099", "06101", "06107", "06111", "06115"
    ],
    "Deaths": [
        165, 44, 162, 29, 69, 39, 15, 225, 12, 26, 1428, 14, 37, 41, 18, 19, 13, 17, 659, 38, 416, 161, 316,
        666, 395, 105, 59, 74, 33, 131, 25, 44, 40, 111, 82, 21, 50, 179, 13
    ],
    "Population": [
        1648556, 208309, 1161413, 193221, 1013581, 136310, 179851, 917673, 153443, 68766, 9829544, 159410,
        260206, 91305, 286461, 437325, 136207, 103487, 3167809, 412300, 2458395, 1588921, 2194710, 3286069,
        815201, 789410, 283159, 737888, 446475, 1885508, 267792, 182139, 451716, 485887, 552999, 99063, 477054,
        839784, 83421
    ],
    "Crude Rate": [
        10.0, 21.1, 13.9, 15.0, 6.8, 28.6, "Unreliable", 24.5, "Unreliable", 37.8, 14.5, "Unreliable", 14.2,
        44.9, "Unreliable", "Unreliable", "Unreliable", "Unreliable", 20.8, 9.2, 16.9, 10.1, 14.4, 20.3, 48.5,
        13.3, 20.8, 10.0, 7.4, 6.9, 9.3, 24.2, 8.9, 22.8, 14.8, 21.2, 10.5, 21.3, "Unreliable"
    ]
}

df2021allfentanyl = pd.DataFrame(data)
print(df2021allfentanyl)
# Out:
#                         County County Code  Deaths  Population  Crude Rate
# 0           Alameda County, CA       06001     165     1648556        10.0
# 1             Butte County, CA       06007      44      208309        21.1
# 2      Contra Costa County, CA       06013     162     1161413        13.9
# 3         El Dorado County, CA       06017      29      193221        15.0
# 4            Fresno County, CA       06019      69     1013581         6.8
# 5          Humboldt County, CA       06023      39      136310        28.6
# 6          Imperial County, CA       06025      15      179851  Unreliable
# 7              Kern County, CA       06029     225      917673        24.5
# 8             Kings County, CA       06031      12      153443  Unreliable
# 9              Lake County, CA       06033      26       68766        37.8
# 10      Los Angeles County, CA       06037    1428     9829544        14.5
# 11           Madera County, CA       06039      14      159410  Unreliable
# 12            Marin County, CA       06041      37      260206        14.2
# 13        Mendocino County, CA       06045      41       91305        44.9
# 14           Merced County, CA       06047      18      286461  Unreliable
# 15         Monterey County, CA       06053      19      437325  Unreliable
# 16             Napa County, CA       06055      13      136207  Unreliable
# 17           Nevada County, CA       06057      17      103487  Unreliable
# 18           Orange County, CA       06059     659     3167809        20.8
# 19           Placer County, CA       06061      38      412300         9.2
# 20        Riverside County, CA       06065     416     2458395        16.9
# 21       Sacramento County, CA       06067     161     1588921        10.1
# 22   San Bernardino County, CA       06071     316     2194710        14.4
# 23        San Diego County, CA       06073     666     3286069        20.3
# 24    San Francisco County, CA       06075     395      815201        48.5
# 25      San Joaquin County, CA       06077     105      789410        13.3
# 26  San Luis Obispo County, CA       06079      59      283159        20.8
# 27        San Mateo County, CA       06081      74      737888        10.0
# 28    Santa Barbara County, CA       06083      33      446475         7.4
# 29      Santa Clara County, CA       06085     131     1885508         6.9
# 30       Santa Cruz County, CA       06087      25      267792         9.3
# 31           Shasta County, CA       06089      44      182139        24.2
# 32           Solano County, CA       06095      40      451716         8.9
# 33           Sonoma County, CA       06097     111      485887        22.8
# 34       Stanislaus County, CA       06099      82      552999        14.8
# 35           Sutter County, CA       06101      21       99063        21.2
# 36           Tulare County, CA       06107      50      477054        10.5
# 37          Ventura County, CA       06111     179      839784        21.3
# 38             Yuba County, CA       06115      13       83421  Unreliable

# %%
df2021allfentanyl['Crude Rate'] = pd.to_numeric(df2021allfentanyl['Crude Rate'], errors='coerce')

# %%
df2021allfentanyl = df2021allfentanyl.dropna(subset=['Crude Rate'])
df2021allfentanyl.rename(columns={'County': 'Location'}, inplace=True)
df1a = df1
df1a["Location"] = df1a["Location"] + ", CA"

# %%
df2021allfentanyl
# Out:
#                       Location County Code  Deaths  Population  Crude Rate
# 0           Alameda County, CA       06001     165     1648556        10.0
# 1             Butte County, CA       06007      44      208309        21.1
# 2      Contra Costa County, CA       06013     162     1161413        13.9
# 3         El Dorado County, CA       06017      29      193221        15.0
# 4            Fresno County, CA       06019      69     1013581         6.8
# 5          Humboldt County, CA       06023      39      136310        28.6
# 7              Kern County, CA       06029     225      917673        24.5
# 9              Lake County, CA       06033      26       68766        37.8
# 10      Los Angeles County, CA       06037    1428     9829544        14.5
# 12            Marin County, CA       06041      37      260206        14.2
# 13        Mendocino County, CA       06045      41       91305        44.9
# 18           Orange County, CA       06059     659     3167809        20.8
# 19           Placer County, CA       06061      38      412300         9.2
# 20        Riverside County, CA       06065     416     2458395        16.9
# 21       Sacramento County, CA       06067     161     1588921        10.1
# 22   San Bernardino County, CA       06071     316     2194710        14.4
# 23        San Diego County, CA       06073     666     3286069        20.3
# 24    San Francisco County, CA       06075     395      815201        48.5
# 25      San Joaquin County, CA       06077     105      789410        13.3
# 26  San Luis Obispo County, CA       06079      59      283159        20.8
# 27        San Mateo County, CA       06081      74      737888        10.0
# 28    Santa Barbara County, CA       06083      33      446475         7.4
# 29      Santa Clara County, CA       06085     131     1885508         6.9
# 30       Santa Cruz County, CA       06087      25      267792         9.3
# 31           Shasta County, CA       06089      44      182139        24.2
# 32           Solano County, CA       06095      40      451716         8.9
# 33           Sonoma County, CA       06097     111      485887        22.8
# 34       Stanislaus County, CA       06099      82      552999        14.8
# 35           Sutter County, CA       06101      21       99063        21.2
# 36           Tulare County, CA       06107      50      477054        10.5
# 37          Ventura County, CA       06111     179      839784        21.3

# %%
dfmerge3 = pd.merge(df1a, df2021allfentanyl, on = "Location")

# %%
df1a
# Out:
#     FIPSCode LocationType                    Location  TimeFrame  \
# 0          6        State              California, CA  2014_2018
# 1       6001       County          Alameda County, CA  2014_2018
# 2       6005       County           Amador County, CA  2014_2018
# 3       6007       County            Butte County, CA  2014_2018
# 4       6009       County        Calaveras County, CA  2014_2018
# 5       6011       County           Colusa County, CA  2014_2018
# 6       6013       County     Contra Costa County, CA  2014_2018
# 7       6015       County        Del Norte County, CA  2014_2018
# 8       6017       County        El Dorado County, CA  2014_2018
# 9       6019       County           Fresno County, CA  2014_2018
# 10      6021       County            Glenn County, CA  2014_2018
# 11      6023       County         Humboldt County, CA  2014_2018
# 12      6025       County         Imperial County, CA  2014_2018
# 13      6027       County             Inyo County, CA  2014_2018
# 14      6029       County             Kern County, CA  2014_2018
# 15      6031       County            Kings County, CA  2014_2018
# 16      6033       County             Lake County, CA  2014_2018
# 17      6035       County           Lassen County, CA  2014_2018
# 18      6037       County      Los Angeles County, CA  2014_2018
# 19      6039       County           Madera County, CA  2014_2018
# 20      6041       County            Marin County, CA  2014_2018
# 21      6043       County         Mariposa County, CA  2014_2018
# 22      6045       County        Mendocino County, CA  2014_2018
# 23      6047       County           Merced County, CA  2014_2018
# 24      6051       County             Mono County, CA  2014_2018
# 25      6053       County         Monterey County, CA  2014_2018
# 26      6055       County             Napa County, CA  2014_2018
# 27      6057       County           Nevada County, CA  2014_2018
# 28      6059       County           Orange County, CA  2014_2018
# 29      6061       County           Placer County, CA  2014_2018
# 30      6063       County           Plumas County, CA  2014_2018
# 31      6065       County        Riverside County, CA  2014_2018
# 32      6067       County       Sacramento County, CA  2014_2018
# 33      6069       County       San Benito County, CA  2014_2018
# 34      6071       County   San Bernardino County, CA  2014_2018
# 35      6073       County        San Diego County, CA  2014_2018
# 36      6075       County    San Francisco County, CA  2014_2018
# 37      6077       County      San Joaquin County, CA  2014_2018
# 38      6079       County  San Luis Obispo County, CA  2014_2018
# 39      6081       County        San Mateo County, CA  2014_2018
# 40      6083       County    Santa Barbara County, CA  2014_2018
# 41      6085       County      Santa Clara County, CA  2014_2018
# 42      6087       County       Santa Cruz County, CA  2014_2018
# 43      6089       County           Shasta County, CA  2014_2018
# 44      6093       County         Siskiyou County, CA  2014_2018
# 45      6095       County           Solano County, CA  2014_2018
# 46      6097       County           Sonoma County, CA  2014_2018
# 47      6099       County       Stanislaus County, CA  2014_2018
# 48      6101       County           Sutter County, CA  2014_2018
# 49      6103       County           Tehama County, CA  2014_2018
# 50      6105       County          Trinity County, CA  2014_2018
# 51      6107       County           Tulare County, CA  2014_2018
# 52      6109       County         Tuolumne County, CA  2014_2018
# 53      6111       County          Ventura County, CA  2014_2018
# 54      6113       County             Yolo County, CA  2014_2018
# 55      6115       County             Yuba County, CA  2014_2018
#
#           DataFormat    Data
# 0   Gini Coefficient  0.4891
# 1   Gini Coefficient  0.4624
# 2   Gini Coefficient     NaN
# 3   Gini Coefficient  0.4893
# 4   Gini Coefficient     NaN
# 5   Gini Coefficient     NaN
# 6   Gini Coefficient  0.4703
# 7   Gini Coefficient     NaN
# 8   Gini Coefficient  0.4494
# 9   Gini Coefficient  0.4785
# 10  Gini Coefficient     NaN
# 11  Gini Coefficient  0.4754
# 12  Gini Coefficient  0.4768
# 13  Gini Coefficient     NaN
# 14  Gini Coefficient  0.4645
# 15  Gini Coefficient  0.4346
# 16  Gini Coefficient  0.4796
# 17  Gini Coefficient  0.4231
# 18  Gini Coefficient  0.5022
# 19  Gini Coefficient  0.4408
# 20  Gini Coefficient  0.5158
# 21  Gini Coefficient     NaN
# 22  Gini Coefficient  0.4736
# 23  Gini Coefficient  0.4708
# 24  Gini Coefficient     NaN
# 25  Gini Coefficient  0.4619
# 26  Gini Coefficient  0.4719
# 27  Gini Coefficient  0.4634
# 28  Gini Coefficient  0.4700
# 29  Gini Coefficient  0.4474
# 30  Gini Coefficient     NaN
# 31  Gini Coefficient  0.4547
# 32  Gini Coefficient  0.4583
# 33  Gini Coefficient  0.3989
# 34  Gini Coefficient  0.4410
# 35  Gini Coefficient  0.4630
# 36  Gini Coefficient  0.5128
# 37  Gini Coefficient  0.4546
# 38  Gini Coefficient  0.4538
# 39  Gini Coefficient  0.4852
# 40  Gini Coefficient  0.4798
# 41  Gini Coefficient  0.4652
# 42  Gini Coefficient  0.4826
# 43  Gini Coefficient  0.4603
# 44  Gini Coefficient     NaN
# 45  Gini Coefficient  0.4231
# 46  Gini Coefficient  0.4578
# 47  Gini Coefficient  0.4451
# 48  Gini Coefficient  0.4466
# 49  Gini Coefficient  0.4585
# 50  Gini Coefficient     NaN
# 51  Gini Coefficient  0.4755
# 52  Gini Coefficient     NaN
# 53  Gini Coefficient  0.4476
# 54  Gini Coefficient  0.4931
# 55  Gini Coefficient  0.4276

# %%
x = dfmerge3["Data"]
y = dfmerge3["Crude Rate"]
plt.scatter(x,y)
plt.title("Gini Index vs Fentanyl Crude Rate 2021 All Ages")
plt.xlabel("Gini Index")
plt.ylabel("Crude Rate")
# Out:
# Text(0, 0.5, 'Crude Rate')

# %%
import pandas as pd

data = {
    'County': ['Alameda County, CA', 'Contra Costa County, CA', 'Kern County, CA', 'Los Angeles County, CA', 'Orange County, CA', 'Riverside County, CA', 'Sacramento County, CA', 'San Bernardino County, CA', 'San Diego County, CA', 'San Francisco County, CA', 'San Mateo County, CA', 'Santa Clara County, CA', 'Sonoma County, CA', 'Ventura County, CA'],
    'County Code': ['06001', '06013', '06029', '06037', '06059', '06065', '06067', '06071', '06073', '06075', '06081', '06085', '06097', '06111'],
    'Deaths': [14, 29, 35, 221, 115, 60, 20, 31, 100, 68, 14, 16, 23, 35],
    'Population': [1666753, 1150215, 896764, 10105518, 3185968, 2450758, 1540975, 2171603, 3343364, 883305, 769545, 1937570, 499942, 850967],
    'Crude Rate': ['Unreliable', 2.5, 3.9, 2.2, 3.6, 2.4, 1.3, 1.4, 3.0, 7.7, 'Unreliable', 'Unreliable', 4.6, 4.1]
}

dffentanyl2018all = pd.DataFrame(data)

print(dffentanyl2018all)
# Out:
#                        County County Code  Deaths  Population  Crude Rate
# 0          Alameda County, CA       06001      14     1666753  Unreliable
# 1     Contra Costa County, CA       06013      29     1150215         2.5
# 2             Kern County, CA       06029      35      896764         3.9
# 3      Los Angeles County, CA       06037     221    10105518         2.2
# 4           Orange County, CA       06059     115     3185968         3.6
# 5        Riverside County, CA       06065      60     2450758         2.4
# 6       Sacramento County, CA       06067      20     1540975         1.3
# 7   San Bernardino County, CA       06071      31     2171603         1.4
# 8        San Diego County, CA       06073     100     3343364         3.0
# 9    San Francisco County, CA       06075      68      883305         7.7
# 10       San Mateo County, CA       06081      14      769545  Unreliable
# 11     Santa Clara County, CA       06085      16     1937570  Unreliable
# 12          Sonoma County, CA       06097      23      499942         4.6
# 13         Ventura County, CA       06111      35      850967         4.1

# %%
dffentanyl2018all['Crude Rate'] = pd.to_numeric(dffentanyl2018all['Crude Rate'], errors='coerce')
dffentanyl2018all.dropna(subset=['Crude Rate'], inplace=True)
dffentanyl2018all.rename(columns={'County': 'Location'}, inplace=True)

# %%
dfmerge4 = pd.merge(df1, dffentanyl2018all, on = "Location")

# %%
dfmerge4
# Out:
#     FIPSCode LocationType                   Location  TimeFrame  \
# 0       6013       County    Contra Costa County, CA  2014_2018
# 1       6029       County            Kern County, CA  2014_2018
# 2       6037       County     Los Angeles County, CA  2014_2018
# 3       6059       County          Orange County, CA  2014_2018
# 4       6065       County       Riverside County, CA  2014_2018
# 5       6067       County      Sacramento County, CA  2014_2018
# 6       6071       County  San Bernardino County, CA  2014_2018
# 7       6073       County       San Diego County, CA  2014_2018
# 8       6075       County   San Francisco County, CA  2014_2018
# 9       6097       County          Sonoma County, CA  2014_2018
# 10      6111       County         Ventura County, CA  2014_2018
#
#           DataFormat    Data County Code  Deaths  Population  Crude Rate
# 0   Gini Coefficient  0.4703       06013      29     1150215         2.5
# 1   Gini Coefficient  0.4645       06029      35      896764         3.9
# 2   Gini Coefficient  0.5022       06037     221    10105518         2.2
# 3   Gini Coefficient  0.4700       06059     115     3185968         3.6
# 4   Gini Coefficient  0.4547       06065      60     2450758         2.4
# 5   Gini Coefficient  0.4583       06067      20     1540975         1.3
# 6   Gini Coefficient  0.4410       06071      31     2171603         1.4
# 7   Gini Coefficient  0.4630       06073     100     3343364         3.0
# 8   Gini Coefficient  0.5128       06075      68      883305         7.7
# 9   Gini Coefficient  0.4578       06097      23      499942         4.6
# 10  Gini Coefficient  0.4476       06111      35      850967         4.1

# %%
x = dfmerge4["Data"]
y = dfmerge4["Crude Rate"]
plt.scatter(x,y)
plt.title("Gini Index vs Fentanyl Crude Rate 2018 All Ages")
plt.xlabel("Gini Index")
plt.ylabel("Crude Rate")
# Out:
# Text(0, 0.5, 'Crude Rate')

# %%
import pandas as pd

data = {
    'County': [
        "Alameda County, CA", "Contra Costa County, CA", "El Dorado County, CA", "Fresno County, CA",
        "Humboldt County, CA", "Imperial County, CA", "Kern County, CA", "Los Angeles County, CA",
        "Marin County, CA", "Mendocino County, CA", "Merced County, CA", "Monterey County, CA",
        "Nevada County, CA", "Orange County, CA", "Placer County, CA", "Riverside County, CA",
        "Sacramento County, CA", "San Bernardino County, CA", "San Diego County, CA",
        "San Francisco County, CA", "San Joaquin County, CA", "San Luis Obispo County, CA",
        "San Mateo County, CA", "Santa Barbara County, CA", "Santa Clara County, CA",
        "Santa Cruz County, CA", "Shasta County, CA", "Solano County, CA", "Sonoma County, CA",
        "Stanislaus County, CA", "Tulare County, CA", "Ventura County, CA"
    ],
    'County Code': [
        "06001", "06013", "06017", "06019", "06023", "06025", "06029", "06037", "06041",
        "06045", "06047", "06053", "06057", "06059", "06061", "06065", "06067", "06071",
        "06073", "06075", "06077", "06079", "06081", "06083", "06085", "06087", "06089",
        "06095", "06097", "06099", "06107", "06111"
    ],
    'Deaths': [
        121, 111, 14, 46, 11, 18, 141, 1002, 23, 14, 19, 23, 20, 396, 27, 284, 55, 237, 416,
        381, 51, 34, 61, 10, 94, 13, 11, 28, 103, 57, 29, 89
    ],
    'Population': [
        1662323, 1152333, 192925, 1000918, 134977, 180267, 901362, 9943046, 257332, 86061,
        279252, 430906, 99606, 3166857, 402950, 2489188, 1559146, 2189183, 3332427, 866606,
        767967, 282249, 758308, 444766, 1907105, 269925, 179027, 446935, 489819, 550081,
        468680, 841387
    ],
    'Crude Rate': [
        7.3, 9.6, 'Unreliable', 4.6, 'Unreliable', 'Unreliable', 15.6, 10.1, 8.9, 'Unreliable',
        'Unreliable', 5.3, 20.1, 12.5, 6.7, 11.4, 3.5, 10.8, 12.5, 44.0, 6.6, 12.0, 8.0,
        'Unreliable', 4.9, 'Unreliable', 'Unreliable', 6.3, 21.0, 10.4, 6.2, 10.6
    ]
}

df2020fentanylall = pd.DataFrame(data)
print(df2020fentanylall)
# Out:
#                         County County Code  Deaths  Population  Crude Rate
# 0           Alameda County, CA       06001     121     1662323         7.3
# 1      Contra Costa County, CA       06013     111     1152333         9.6
# 2         El Dorado County, CA       06017      14      192925  Unreliable
# 3            Fresno County, CA       06019      46     1000918         4.6
# 4          Humboldt County, CA       06023      11      134977  Unreliable
# 5          Imperial County, CA       06025      18      180267  Unreliable
# 6              Kern County, CA       06029     141      901362        15.6
# 7       Los Angeles County, CA       06037    1002     9943046        10.1
# 8             Marin County, CA       06041      23      257332         8.9
# 9         Mendocino County, CA       06045      14       86061  Unreliable
# 10           Merced County, CA       06047      19      279252  Unreliable
# 11         Monterey County, CA       06053      23      430906         5.3
# 12           Nevada County, CA       06057      20       99606        20.1
# 13           Orange County, CA       06059     396     3166857        12.5
# 14           Placer County, CA       06061      27      402950         6.7
# 15        Riverside County, CA       06065     284     2489188        11.4
# 16       Sacramento County, CA       06067      55     1559146         3.5
# 17   San Bernardino County, CA       06071     237     2189183        10.8
# 18        San Diego County, CA       06073     416     3332427        12.5
# 19    San Francisco County, CA       06075     381      866606        44.0
# 20      San Joaquin County, CA       06077      51      767967         6.6
# 21  San Luis Obispo County, CA       06079      34      282249        12.0
# 22        San Mateo County, CA       06081      61      758308         8.0
# 23    Santa Barbara County, CA       06083      10      444766  Unreliable
# 24      Santa Clara County, CA       06085      94     1907105         4.9
# 25       Santa Cruz County, CA       06087      13      269925  Unreliable
# 26           Shasta County, CA       06089      11      179027  Unreliable
# 27           Solano County, CA       06095      28      446935         6.3
# 28           Sonoma County, CA       06097     103      489819        21.0
# 29       Stanislaus County, CA       06099      57      550081        10.4
# 30           Tulare County, CA       06107      29      468680         6.2
# 31          Ventura County, CA       06111      89      841387        10.6

# %%
df2020fentanylall['Crude Rate'] = pd.to_numeric(df2020fentanylall['Crude Rate'], errors='coerce')
df2020fentanylall.dropna(subset=['Crude Rate'], inplace=True)
df2020fentanylall.rename(columns={'County': 'Location'}, inplace=True)

# %%
dfmerge5 = pd.merge(df1, df2020fentanylall, on = "Location")

# %%
x = dfmerge5["Data"]
y = dfmerge5["Crude Rate"]
plt.scatter(x,y)
plt.title("Gini Index vs Fentanyl Crude Rate 2020 All Ages")
plt.xlabel("Gini Index")
plt.ylabel("Crude Rate")
# Out:
# Text(0, 0.5, 'Crude Rate')

# %%
import pandas as pd

data = {
    'County': [
        "Alameda County, CA", "Contra Costa County, CA", "Fresno County, CA", "Kern County, CA",
        "Los Angeles County, CA", "Marin County, CA", "Orange County, CA", "Riverside County, CA",
        "Sacramento County, CA", "San Bernardino County, CA", "San Diego County, CA",
        "San Francisco County, CA", "San Joaquin County, CA", "San Mateo County, CA",
        "Santa Barbara County, CA", "Santa Clara County, CA", "Solano County, CA", "Sonoma County, CA",
        "Stanislaus County, CA", "Ventura County, CA"
    ],
    'County Code': [
        "06001", "06013", "06019", "06029", "06037", "06041", "06059", "06065", "06067", "06071",
        "06073", "06075", "06077", "06081", "06083", "06085", "06095", "06097", "06099", "06111"
    ],
    'Deaths': [
        57, 51, 18, 54, 420, 11, 138, 135, 42, 69, 152, 197, 14, 39, 16, 30, 19, 44, 15, 41
    ],
    'Population': [
        1671329, 1153526, 999101, 900202, 10039107, 258826, 3175692, 2470546, 1552058, 2180085,
        3338330, 881549, 762148, 766573, 446499, 1927852, 447643, 494336, 550660, 846006
    ],
    'Crude Rate': [
        3.4, 4.4, 'Unreliable', 6.0, 4.2, 'Unreliable', 4.3, 5.5, 2.7, 3.2, 4.6, 22.3, 'Unreliable',
        5.1, 'Unreliable', 1.6, 'Unreliable', 8.9, 'Unreliable', 4.8
    ]
}

df2019fentanylallages = pd.DataFrame(data)
print(df2019fentanylallages)
# Out:
#                        County County Code  Deaths  Population  Crude Rate
# 0          Alameda County, CA       06001      57     1671329         3.4
# 1     Contra Costa County, CA       06013      51     1153526         4.4
# 2           Fresno County, CA       06019      18      999101  Unreliable
# 3             Kern County, CA       06029      54      900202         6.0
# 4      Los Angeles County, CA       06037     420    10039107         4.2
# 5            Marin County, CA       06041      11      258826  Unreliable
# 6           Orange County, CA       06059     138     3175692         4.3
# 7        Riverside County, CA       06065     135     2470546         5.5
# 8       Sacramento County, CA       06067      42     1552058         2.7
# 9   San Bernardino County, CA       06071      69     2180085         3.2
# 10       San Diego County, CA       06073     152     3338330         4.6
# 11   San Francisco County, CA       06075     197      881549        22.3
# 12     San Joaquin County, CA       06077      14      762148  Unreliable
# 13       San Mateo County, CA       06081      39      766573         5.1
# 14   Santa Barbara County, CA       06083      16      446499  Unreliable
# 15     Santa Clara County, CA       06085      30     1927852         1.6
# 16          Solano County, CA       06095      19      447643  Unreliable
# 17          Sonoma County, CA       06097      44      494336         8.9
# 18      Stanislaus County, CA       06099      15      550660  Unreliable
# 19         Ventura County, CA       06111      41      846006         4.8

# %%
df2019fentanylallages['Crude Rate'] = pd.to_numeric(df2019fentanylallages['Crude Rate'], errors='coerce')
df2019fentanylallages.dropna(subset=['Crude Rate'], inplace=True)
df2019fentanylallages.rename(columns={'County': 'Location'}, inplace=True)

# %%
dfmerge6 = pd.merge(df1, df2019fentanylallages, on = "Location")

# %%
x = dfmerge6["Data"]
y = dfmerge6["Crude Rate"]
plt.scatter(x,y)
plt.title("Gini Index vs Fentanyl Crude Rate 2019 All Ages")
plt.xlabel("Gini Index")
plt.ylabel("Crude Rate")
# Out:
# Text(0, 0.5, 'Crude Rate')
