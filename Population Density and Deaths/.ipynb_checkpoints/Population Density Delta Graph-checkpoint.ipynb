# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
countyareas = pd.read_csv("areaofcaliforniacounties.txt")
countypopulation2016 = pd.read_csv("CaPopulations2016.csv")
countypopulation2021 = pd.read_csv("PopulationofCA2021.csv")
fentanyl2016 = pd.read_csv("FentanylAll2016.csv")
fentanyl2021 = pd.read_csv("NewFentanyl2021AllAges.csv")
plt.rcParams["figure.figsize"] = (20,15)

# %%
def delta(areas,pop1,pop2,rate1,rate2):
    areas["county"] = areas["county"] + " County"
    pop1 = pop1.rename(columns={'population': 'pop1'})
    pop2 = pop2.rename(columns={'population': 'pop2'})
    populations1 = pd.merge(areas,pop1)
    populations2 = pd.merge(areas, pop2)
    combinedpop = pd.merge(populations1,populations2)
    combinedpop['density1'] = combinedpop['pop1']/combinedpop['area']
    combinedpop['density2'] = combinedpop['pop2']/combinedpop['area']
    combinedpop['subdensity'] = combinedpop['density2'] - combinedpop['density1']
    rate1['county'] = rate1['county'] + " County"
    rate1 = rate1.rename(columns={'rate': 'rate1'})
    rate2 = rate2.rename(columns={'rate': 'rate2'})
    rate2['county'] = rate2['county'] + " County"
    rate2 = rate2.drop("num1", axis = 1)
    rate2 = rate2.drop("num2", axis = 1)
    rate2 = rate2.drop("num3", axis = 1)
    rate2 = rate2.drop("deaths", axis = 1)
    combineddf = pd.merge(combinedpop, rate1)
    combineddf2 = pd.merge(combineddf, rate2)
    combineddf2['subrate'] = combineddf2['rate2'] - combineddf2['rate1']
    combineddf2['delta'] = combineddf2['subrate'] / combineddf2['subdensity']
    x = combineddf2['density2']
    y = combineddf2['delta']
    plt.xlabel("Density of County")
    plt.ylabel("Delta")
    plot = plt.scatter(x,y)

# %%
delta(countyareas,countypopulation2016,countypopulation2021,fentanyl2016,fentanyl2021)

# %%
fentanyl2016
# Out:
#              county    rate    num1      num2    num3  deaths
# 0           Trinity  7.8225  2.1325   41.6775  3.9125       1
# 1              Inyo  5.5125  1.5025   29.3600  2.7550       1
# 2         Calaveras  4.4275  1.9125   14.8525  1.5650       2
# 3         Del Norte  3.6300  0.9900   19.3400  1.8150       1
# 4            Amador  2.6750  0.7300   14.2525  1.3375       1
# 5          Siskiyou  2.2925  0.6250   12.2175  1.1475       1
# 6          Tuolumne  1.8575  0.5075    9.9025  0.9300       1
# 7     San Francisco  1.8400  1.0875    2.9525  0.4400      16
# 8              Lake  1.5600  0.4250    8.3050  0.7800       1
# 9              Yuba  1.3275  0.3625    7.0775  0.6650       1
# 10        Mendocino  1.1400  0.3100    6.0800  0.5700       1
# 11           Merced  1.1175  0.4250    3.1050  0.4475       3
# 12           Orange  1.0400  0.7225    1.4550  0.1800      33
# 13           Nevada  1.0100  0.2750    5.3725  0.5050       1
# 14             Yolo  0.9275  0.4000    3.1075  0.3275       2
# 15        San Diego  0.9025  0.6125    1.2875  0.1625      30
# 16       Sacramento  0.8575  0.5075    1.4225  0.2125      13
# 17           Sonoma  0.8000  0.2200    2.0400  0.4000       4
# 18         Humboldt  0.7325  0.2000    3.8975  0.3650       1
# 19       Santa Cruz  0.7300  0.2000    2.5350  0.3650       2
# 20      San Joaquin  0.6850  0.2875    1.5400  0.2525       5
# 21       California  0.6075  0.5375    0.6925  0.0400     239
# 22      Los Angeles  0.5725  0.4375    0.7350  0.0725      58
# 23           Shasta  0.5575  0.1525    2.9625  0.2775       1
# 24          Alameda  0.5450  0.2700    1.0225  0.1725       9
# 25        El Dorado  0.5375  0.1475    2.8725  0.2700       1
# 26           Placer  0.5250  0.1450    1.8300  0.2650       2
# 27      Santa Clara  0.5225  0.2850    0.9275  0.1400      10
# 28          Ventura  0.4700  0.2050    1.1450  0.1650       4
# 29    Santa Barbara  0.4500  0.1200    1.5650  0.2250       2
# 30            Butte  0.4400  0.1200    2.3500  0.2200       1
# 31        Riverside  0.4200  0.2275    0.7450  0.1150      10
# 32           Fresno  0.4100  0.1425    1.0225  0.1725       4
# 33            Marin  0.3825  0.1050    2.0475  0.1925       1
# 34     Contra Costa  0.3500  0.1250    0.8775  0.1525       4
# 35        San Mateo  0.2600  0.0700    0.9100  0.1300       2
# 36   San Bernardino  0.2350  0.0775    0.5450  0.1000       5
# 37         Monterey  0.2300  0.0625    1.2250  0.1150       1
# 38             Kern  0.2250  0.0975    0.7600  0.0800       2
# 39       Stanislaus  0.1850  0.0500    0.9825  0.0925       1
# 40           Alpine  0.0000  0.0000  344.4300  0.0000       0
# 41           Colusa  0.0000  0.0000   17.0900  0.0000       0
# 42            Glenn  0.0000  0.0000   13.1300  0.0000       0
# 43         Imperial  0.0000  0.0000    2.0400  0.0000       0
# 44            Kings  0.0000  0.0000    2.4600  0.0000       0
# 45           Lassen  0.0000  0.0000   11.9500  0.0000       0
# 46           Madera  0.0000  0.0000    2.3800  0.0000       0
# 47         Mariposa  0.0000  0.0000   21.1900  0.0000       0
# 48            Modoc  0.0000  0.0000   41.9400  0.0000       0
# 49             Mono  0.0000  0.0000   26.3800  0.0000       0
# 50             Napa  0.0000  0.0000    2.5900  0.0000       0
# 51           Plumas  0.0000  0.0000   19.8000  0.0000       0
# 52       San Benito  0.0000  0.0000    6.2100  0.0000       0
# 53  San Luis Obispo  0.0000  0.0000    1.3000  0.0000       0
# 54           Sierra  0.0000  0.0000  125.1700  0.0000       0
# 55           Solano  0.0000  0.0000    0.8400  0.0000       0
# 56           Sutter  0.0000  0.0000    3.8200  0.0000       0
# 57           Tehama  0.0000  0.0000    5.8300  0.0000       0
# 58           Tulare  0.0000  0.0000    0.8000  0.0000       0
# 59          Unknown     NaN  0.0000       NaN     NaN       0
