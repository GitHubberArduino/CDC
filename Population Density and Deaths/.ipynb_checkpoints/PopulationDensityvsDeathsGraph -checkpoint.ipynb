# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sympy import *
import lmfit
from lmfit import Parameters, minimize
from lmfit.printfuncs import report_fit

# %%
Capopulation = pd.read_csv("PopulationofCA2021.csv")
Capopulation2010 = pd.read_csv("CAPopulation2010.csv")
Capopulation2011 = pd.read_csv("2011CApopulation.csv")
Capopulation2016 = pd.read_csv("Capopulations2016.csv")
ages1524anyopioid2021 = pd.read_csv("Ages1524anyopioid2021.csv")
population15242021 = pd.read_csv("15to24population.csv")
ages1524fentanyl2021 = pd.read_csv("1524fentanyl2021.csv")
population2020 = pd.read_csv("CApopulation2020.csv")
population2019 = pd.read_csv("CApopulation2019.csv")

# %%
plt.rcParams["figure.figsize"] = (20,30)

# %%
areas = pd.read_csv("areaofcaliforniacounties.txt")

# %%
areas
# Out:
#         area           county
# 0   20056.92   San Bernardino
# 1   10180.87             Inyo
# 2    8131.91             Kern
# 3    7206.47        Riverside
# 4    6277.88         Siskiyou
# 5    5957.99           Fresno
# 6    4824.21           Tulare
# 7    4541.18           Lassen
# 8    4206.63        San Diego
# 9    4176.60         Imperial
# 10   4057.88      Los Angeles
# 11   3917.77            Modoc
# 12   3775.40           Shasta
# 13   3567.98         Humboldt
# 14   3506.34        Mendocino
# 15   3298.56  San Luis Obispo
# 16   3280.59         Monterey
# 17   3179.25          Trinity
# 18   3048.98             Mono
# 19   2949.71           Tehama
# 20   2735.08    Santa Barbara
# 21   2553.04           Plumas
# 22   2220.88         Tuolumne
# 23   2137.07           Madera
# 24   1934.97           Merced
# 25   1843.13          Ventura
# 26   1707.88        El Dorado
# 27   1636.46            Butte
# 28   1575.85           Sonoma
# 29   1494.83       Stanislaus
# ...

# %%
22786/1150.73
# Out:
# 19.801343494998825

# %%
populations = pd.merge(areas, Capopulation)
populations2010 = pd.merge(areas, Capopulation2010)
populations2011 = pd.merge(areas, Capopulation2011)
populations2016 = pd.merge(areas, Capopulation2016)
population2019 = pd.merge(areas, population2020)
population2020 = pd.merge(areas, population2019)

# %%
populations["density"] = populations['population']/populations['area']
populations2010['density'] = populations2010['population']/populations2010['area']
populations2011['density'] = populations2011['population']/populations2011['area']
populations2016['density'] = populations2016['population']/populations2016['area']
population2019['density'] = populations2016['population']/populations2016['area']
population2020['density'] = populations2016['population']/populations2016['area']

# %%
populations.to_csv('PopulationDensity2021.csv', index=False)

# %%
anyopioid2021allagesdeaths = pd.read_csv("New2021County.csv")
anyopioid2021allagesdeaths2 = anyopioid2021allagesdeaths.drop(2, axis = 0)

# %%
anyopioid2021allagesdeaths2['county'] = anyopioid2021allagesdeaths2['county'] + " County"

# %%
populationanddeath = pd.merge(populations, anyopioid2021allagesdeaths2)

# %%
plt.rcParams["figure.figsize"] = (20,20)

# %%
plt.scatter(populationanddeath['density'], populationanddeath['rate'])
plt.title("2021 Any Opioid All Ages Without San Francisco Rates")
plt.xlabel("Population Density")
plt.ylabel("Crude Rate Per 100K")
# Out:
# Text(0, 0.5, 'Crude Rate Per 100K')

# %%
plt.scatter(populationanddeath['density'], populationanddeath['deaths'])
plt.title("2021 Any Opioid All Ages Without San Francisco Deaths")
plt.xlabel("Population Density")
plt.ylabel("Deaths")
# Out:
# Text(0, 0.5, 'Deaths')

# %% [markdown]
# ### plt.scatter(populationanddeath['density'], populationanddeath['deaths'])
# plt.title("2021 Any Opioid All Ages Without San Francisco Deaths")

# %%
fentanyl2021allagesdeaths = pd.read_csv("NewFentanyl2021AllAges.csv")
fentanyl2021allagesdeaths['county'] = fentanyl2021allagesdeaths['county'] + " County"
fentanyl2021allagesdeaths = fentanyl2021allagesdeaths.replace(" Colusa County" , "Colusa County")

# %%
fentanyl2021allagesdeaths = fentanyl2021allagesdeaths.drop('num1', axis = 1)
fentanyl2021allagesdeaths = fentanyl2021allagesdeaths.drop('num2', axis = 1)
fentanyl2021allagesdeaths = fentanyl2021allagesdeaths.drop('num3', axis = 1)
fentanyl2021allagesdeaths = fentanyl2021allagesdeaths.rename(columns = {'rate' : 'fentanyl2021allagesrate', 'deaths' : 'deathsfromfentanyl'})

# %%
fentanyl2021all = fentanyl2021allagesdeaths.drop(2, axis = 0)
fentanyl2021all
# Out:
#                     county  fentanyl2021allagesrate  deathsfromfentanyl
# 0            Alpine County                  88.2625                   1
# 1         Mendocino County                  45.3000                  40
# 3              Lake County                  40.5150                  26
# 4           Trinity County                  30.3500                   4
# 5          Humboldt County                  26.8200                  36
# 6              Kern County                  24.1150                 222
# 7            Shasta County                  23.2350                  41
# 8         Del Norte County                  22.3550                   6
# 9              Inyo County                  22.0100                   4
# 10           Sonoma County                  20.9650                 105
# 11           Orange County                  20.2250                 649
# 12           Sutter County                  20.1575                  20
# ...

# %%
populationanddeath2 = pd.merge(populations,fentanyl2021all)

# %%
plt.scatter(populationanddeath2['density'],populationanddeath2['deathsfromfentanyl'])
plt.title("fentanyl2021 all ages clean deaths")
plt.xlabel("Population Density")
plt.ylabel("Deaths")
# Out:
# Text(0, 0.5, 'Deaths')

# %%
plt.scatter(populationanddeath2['density'],populationanddeath2['fentanyl2021allagesrate'])
plt.title("fentanyl2021 crude rates")
plt.xlabel("Population Density")
plt.ylabel("Crude Rate")
# Out:
# Text(0, 0.5, 'Crude Rate')

# %%
opioid2016allages = pd.read_csv("2016anyopioidallages.txt.csv")
opioid2016allages['county'] = opioid2016allages['county'] + " County"
opioid2016allages2 = opioid2016allages.drop(12, axis = 0)

# %%
populationanddeath3 = pd.merge(populations2016,opioid2016allages2)

# %%
plt.scatter(populationanddeath3['density'],populationanddeath3['deaths'])
plt.title("any opioid 2016 all ages clean deaths without San Francisco")
plt.xlabel("Population Density")
plt.ylabel("Clean Deaths")
# Out:
# Text(0, 0.5, 'Clean Deaths')

# %%
plt.scatter(populationanddeath3['density'],populationanddeath3['rate'])
plt.title("any opioid 2016 all ages crude rates without San Francisco")
plt.xlabel("Population Density")
plt.ylabel("Crude Rate")
# Out:
# Text(0, 0.5, 'Crude Rate')

# %%
opioid2010allages = pd.read_csv("2010anyopioidallages.csv")
opioid2010allages['county'] = opioid2010allages['county'] + " County"
opioid2010allages2 = opioid2010allages.drop(11, axis = 0)

# %%
populationanddeath4 = pd.merge(populations2010,opioid2010allages2)

# %%
populationanddeath2
# Out:
#         area                  county  population      density  \
# 0   20056.92   San Bernardino County     2200340   109.704780
# 1   10180.87             Inyo County       18172     1.784916
# 2    8131.91             Kern County      920651   113.214608
# 3    7206.47        Riverside County     2477971   343.853648
# 4    6277.88         Siskiyou County       43315     6.899622
# 5    5957.99           Fresno County     1021649   171.475447
# 6    4824.21           Tulare County      481649    99.839974
# 7    4541.18           Lassen County       29965     6.598505
# 8    4206.63        San Diego County     3343827   794.894488
# 9    4176.60         Imperial County      191619    45.879184
# 10   4057.88      Los Angeles County    10198389  2513.230800
# 11   3917.77            Modoc County        9384     2.395240
# 12   3775.40           Shasta County      176451    46.737034
# 13   3567.98         Humboldt County      134214    37.616242
# ...

# %%
plt.scatter(populationanddeath2['density'],populationanddeath2['fentanyl2021allagesrate'], s=100, color='tab:green')
plt.scatter(populationanddeath3['density'],populationanddeath3['rate'], s=100, color='tab:blue')
plt.scatter(populationanddeath4['density'],populationanddeath4['rate'], s=100, color='tab:pink')
plt.title("Fentanyl All Ages Population Density vs Rate")
plt.xlabel("Population Density")
plt.ylabel("rate")
plt.legend(['2021', '2016', '2010'])

# %%
plt.rcParams["figure.figsize"] = (20,15)

# %%
plt.scatter(populationanddeath2['density'],populationanddeath2['deathsfromfentanyl'], s=100, color='tab:green')
plt.scatter(populationanddeath3['density'],populationanddeath3['deaths'], s=100, color='tab:blue')
plt.scatter(populationanddeath4['density'],populationanddeath4['deaths'], s=100, color='tab:pink')
plt.title("Fentanyl All Ages Population Density vs deaths")
plt.title("Fentanyl All Ages Population Density vs Deaths")
plt.xlabel("Population Density")
plt.ylabel("deaths")
plt.legend(['2021', '2016', '2010'])

# %%
fentanyl2011allages = pd.read_csv("fentanyl2011.csv")
fentanyl2011allages['county'] = fentanyl2011allages['county'] + " County"
fentanyl2011allages
# Out:
#                     county    rate    num1      num2    num3  deaths
# 0         Calaveras County  4.4350  1.2100   15.4450  2.2150       2
# 1              Lake County  3.1125  1.3425   10.4375  1.1000       2
# 2            Lassen County  2.9150  0.7950   15.5350  1.4575       1
# 3            Amador County  2.6650  0.7250   14.1925  1.3325       1
# 4        Santa Cruz County  1.1325  0.3075    3.2500  0.5625       3
# 5     San Francisco County  1.1025  0.5225    2.0725  0.3600       9
# 6   San Luis Obispo County  0.7350  0.2000    2.5700  0.3700       2
# 7            Madera County  0.6575  0.1800    3.5050  0.3300       1
# 8            Sonoma County  0.6150  0.3175    1.6450  0.1775       3
# 9       Santa Clara County  0.5500  0.2725    1.0050  0.1700      10
# 10           Solano County  0.4800  0.1300    1.6750  0.2400       2
# 11        San Diego County  0.4775  0.2725    0.7825  0.1200      15
# 12         Monterey County  0.4750  0.2050    1.5950  0.1675       2
# ...

# %%
fentanyl2011allages2 = fentanyl2011allages.drop(5, axis = 0)
populationanddeath5 = pd.merge(populations2011,fentanyl2011allages2)

# %%
populationanddeath5
# Out:
#         area                  county  population      density    rate    num1  \
# 0   20056.92   San Bernardino County     2065910   103.002355  0.0000  0.0000
# 1   10180.87             Inyo County       18559     1.822929  0.0000  0.0000
# 2    8131.91             Kern County      850777   104.622038  0.2350  0.0650
# 3    7206.47        Riverside County     2231323   309.627737  0.2250  0.0950
# 4    6277.88         Siskiyou County       44885     7.149707  0.0000  0.0000
# 5    5957.99           Fresno County      943807   158.410303  0.3200  0.1225
# 6    4824.21           Tulare County      448129    92.891686  0.2225  0.0600
# 7    4541.18           Lassen County       34370     7.568517  2.9150  0.7950
# 8    4206.63        San Diego County     3141469   746.789948  0.4775  0.2725
# 9    4176.60         Imperial County      177931    42.601877  0.0000  0.0000
# 10   4057.88      Los Angeles County     9910160  2442.201347  0.0600  0.0250
# ...

# %%
plt.scatter(populationanddeath5['density'],populationanddeath5['deaths'])
plt.title("fentanyl 2011 all ages clean deaths without San Francisco")
plt.xlabel("Population Density")
plt.ylabel("Clean deaths3")
# Out:
# Text(0, 0.5, 'Clean deaths')

# %% [markdown]
# plt.scatter(populationanddeath5['density'],populationanddeath5['rate'])
# plt.title("fentanyl 2011 all ages crude rate deaths without San Francisco")

# %%
plt.scatter(populationanddeath5['density'],populationanddeath5['rate'])
plt.title("fentanyl 2011 all ages crude rate deaths without San Francisco")
plt.xlabel("Population")
plt.ylabel("Crude Rates")
# Out:
# Text(0, 0.5, 'Crude Rates')

# %%
plt.scatter(populationanddeath5['density'],populationanddeath5['rate'])
plt.title("fentanyl 2011 all ages crude rate deaths without San Francisco")plt.xlabel("Population")
plt.ylabel("Crude Rates")
# Out:
# Text(0.5, 1.0, 'fentanyl 2011 all ages crude rate deaths without San Francisco')

# %%
fentanyl2016allages = pd.read_csv("fentanylall2016.csv")
fentanyl2016allages['county'] = fentanyl2016allages['county'] + " County"
fentanyl2016allages
# Out:
#                     county    rate    num1      num2    num3  deaths
# 0           Trinity County  7.8225  2.1325   41.6775  3.9125       1
# 1              Inyo County  5.5125  1.5025   29.3600  2.7550       1
# 2         Calaveras County  4.4275  1.9125   14.8525  1.5650       2
# 3         Del Norte County  3.6300  0.9900   19.3400  1.8150       1
# 4            Amador County  2.6750  0.7300   14.2525  1.3375       1
# 5          Siskiyou County  2.2925  0.6250   12.2175  1.1475       1
# 6          Tuolumne County  1.8575  0.5075    9.9025  0.9300       1
# 7     San Francisco County  1.8400  1.0875    2.9525  0.4400      16
# 8              Lake County  1.5600  0.4250    8.3050  0.7800       1
# 9              Yuba County  1.3275  0.3625    7.0775  0.6650       1
# 10        Mendocino County  1.1400  0.3100    6.0800  0.5700       1
# 11           Merced County  1.1175  0.4250    3.1050  0.4475       3
# 12           Orange County  1.0400  0.7225    1.4550  0.1800      33
# ...

# %%
fentanyl2016allages2 = fentanyl2016allages.drop(5, axis = 0)
populationanddeath6 = pd.merge(populations2016,fentanyl2016allages2)
plt.scatter(populationanddeath6['density'],populationanddeath6['rate'])
plt.title("fentanyl 2016 all ages crude rate deaths without San Francisco")
plt.xlabel("Population")
plt.ylabel("Crude Rates")
# Out:
# Text(0, 0.5, 'Crude Rates')

# %%
plt.scatter(populationanddeath6['density'],populationanddeath6['deaths'])
plt.title("fentanyl 2016 all ages clean deaths without San Francisco")
plt.xlabel("Population")
plt.ylabel("Clean Deaths")
# Out:
# Text(0, 0.5, 'Clean Deaths')

# %%
populationanddeath6b = populationanddeath6.drop(55, axis = 0)

# %%
plt.scatter(populationanddeath['density'],populationanddeath['rate'], s=100, color='tab:green')
plt.scatter(populationanddeath6b['density'],populationanddeath6b['rate'], s=100, color='tab:blue')
plt.scatter(populationanddeath5['density'],populationanddeath5['rate'], s=100, color='tab:pink')
plt.title("Any Opioid All Ages Population Density vs Crude Rate")
plt.xlabel("Population Density")
plt.ylabel("rate")
plt.legend(['2021', '2016', '2010'])

# %%
plt.scatter(populationanddeath['density'],populationanddeath['deaths'], s=100, color='tab:green')
plt.scatter(populationanddeath6b['density'],populationanddeath6b['deaths'], s=100, color='tab:blue')
plt.scatter(populationanddeath5['density'],populationanddeath5['deaths'], s=100, color='tab:pink')
plt.title("Any Opioid All Ages Population Density vs Clean Death of County")
plt.xlabel("Population Density")
plt.ylabel("clean death")
plt.legend(['2021', '2016', '2010'])

# %%
populationanddeath
# Out:
#         area                  county  population      density     rate  \
# 0   20056.92   San Bernardino County     2200340   109.704780  16.0875
# 1   10180.87             Inyo County       18172     1.784916  27.5125
# 2    8131.91             Kern County      920651   113.214608  29.7650
# 3    7206.47        Riverside County     2477971   343.853648  20.1375
# 4    6277.88         Siskiyou County       43315     6.899622  18.4700
# 5    5957.99           Fresno County     1021649   171.475447   8.9075
# 6    4824.21           Tulare County      481649    99.839974  11.8350
# 7    4541.18           Lassen County       29965     6.598505  13.3500
# 8    4206.63        San Diego County     3343827   794.894488  21.8000
# 9    4176.60         Imperial County      191619    45.879184   7.8275
# 10   4057.88      Los Angeles County    10198389  2513.230800  15.4250
# 11   3917.77            Modoc County        9384     2.395240  21.3150
# ...

# %%
populationst2021 = pd.merge(areas,ages1524anyopioid2021 )

# %%
populationst2021["density"] = populationst2021['population']/populationst2021['area']
populationst2021 = populationst2021.drop(17, axis = 0)

# %%
plt.scatter(populationst2021['density'],populationst2021['deaths'])
plt.title("Any opioid 2021 clean deaths 15-24")
# Out:
# Text(0.5, 1.0, 'Any opioid 2021 clean deaths 15-24')

# %%
populationstfentanyl2021 = pd.merge(areas, ages1524fentanyl2021 )
populationstfentanyl2021["density"] = populationstfentanyl2021['population']/populationstfentanyl2021['area']
populationstfentanyl2021 = populationstfentanyl2021.drop(17, axis = 0)
plt.scatter(populationstfentanyl2021['density'],populationstfentanyl2021['deaths'])
plt.title("fentanyl 2021 clean deaths 15-24")
# Out:
# Text(0.5, 1.0, 'fentanyl 2021 clean deaths 15-24')

# %%
opioid15192021 = pd.read_csv("Ages1519opioid2021.csv")
opioid15192021['county'] = opioid15192021['county'] + " County"
populationsopioid15192021 = pd.merge(populations, opioid15192021)
populationsopioid15192021 
populations
# Out:
#         area                  county  population       density
# 0   20056.92   San Bernardino County     2200340    109.704780
# 1   10180.87             Inyo County       18172      1.784916
# 2    8131.91             Kern County      920651    113.214608
# 3    7206.47        Riverside County     2477971    343.853648
# 4    6277.88         Siskiyou County       43315      6.899622
# 5    5957.99           Fresno County     1021649    171.475447
# 6    4824.21           Tulare County      481649     99.839974
# 7    4541.18           Lassen County       29965      6.598505
# 8    4206.63        San Diego County     3343827    794.894488
# 9    4176.60         Imperial County      191619     45.879184
# 10   4057.88      Los Angeles County    10198389   2513.230800
# 11   3917.77            Modoc County        9384      2.395240
# 12   3775.40           Shasta County      176451     46.737034
# 13   3567.98         Humboldt County      134214     37.616242
# ...

# %%
def filter_deaths(row):
    if row["deaths"].isdigit():
        return True
    else:
        return False
populationsopioid15192021 = populationsopioid15192021[populationsopioid15192021.apply(filter_deaths, axis=1)]
plt.scatter(populationsopioid15192021['density'],populationsopioid15192021['deaths'])
plt.title("any opioids 15-19 death 2021")
# Out:
# Text(0.5, 1.0, 'any opioids 15-19 death 2021')

# %%
fentanyl15192021 = pd.read_csv("15to19fentanyl2021.csv")
fentanyl15192021['county'] = fentanyl15192021['county'] + " County"
fentanyl15192021 = pd.merge(populations, fentanyl15192021)
fentanyl15192021 = fentanyl15192021.drop(56, axis = 0)
plt.scatter(fentanyl15192021['density'],fentanyl15192021['rate'])
plt.title("fentanyl 15-19 rate 2021")
plt.xlabel("Population")
plt.ylabel("Crude Rates")
# Out:
# Text(0, 0.5, 'Crude Rates')

# %%
fentanyl15192021a = fentanyl15192021[fentanyl15192021.apply(filter_deaths, axis=1)]

# %%
fentanyl15192021b = fentanyl15192021a.sort_values(by = ['deaths'])
fentanyl15192021b
# Out:
#         area                  county  population      density     rate  \
# 22   2220.88         Tuolumne County       51732    23.293469   0.0000
# 48    738.33           Alpine County        1133     1.534544   0.0000
# 43    953.21           Sierra County        3098     3.250071   0.0000
# 42    957.77           Nevada County       98017   102.338766   0.0000
# 40   1006.37        Del Norte County       26840    26.670111   0.0000
# 39   1014.69             Yolo County      225894   222.623658   0.0000
# 38   1020.01        Calaveras County       44153    43.286831   0.0000
# 37   1256.46             Lake County       64174    51.075243   0.0000
# 35   1313.95            Glenn County       29185    22.211652   0.0000
# 30   1448.82         Mariposa County       17571    12.127801   0.0000
# 50    631.84             Yuba County       78123   123.643644   0.0000
# 21   2553.04           Plumas County       19124     7.490678   0.0000
# ...

# %%
plt.scatter(fentanyl15192021b['density'],fentanyl15192021b['deaths'])
plt.title("fentanyl 15-19 death 2021")
# Out:
# Text(0.5, 1.0, 'fentanyl 15-19 death 2021')

# %%
fentanyl15192020 = pd.read_csv("15to19fentanyl2020.csv")
fentanyl15192020['county'] = fentanyl15192020['county'] + " County"
fentanyl15192020 = pd.merge(population2020, fentanyl15192020)
fentanyl15192020 = fentanyl15192020.drop(56, axis = 0)
plt.scatter(fentanyl15192020['density'],fentanyl15192020['rate'])
plt.title("fentanyl 15-19 rate 2020")
plt.xlabel("Population Density")
plt.ylabel("rate")
# Out:
# Text(0, 0.5, 'rate')

# %% [markdown]
# ###

# %%
fentanyl15192020 = fentanyl15192020[fentanyl15192020.apply(filter_deaths, axis=1)]
plt.scatter(fentanyl15192020['density'],fentanyl15192020['deaths'])
plt.title("fentanyl 15-19 death 2020")
plt.xlabel("Population Density")
plt.ylabel("rate")
# Out:
# Text(0, 0.5, 'rate')

# %%
fentanyl15192019 = pd.read_csv("15to19fentanyl2019.csv")
fentanyl15192019['county'] = fentanyl15192019['county'] + " County"
fentanyl15192019 = pd.merge(population2019, fentanyl15192019)
fentanyl15192019 = fentanyl15192019.drop(56, axis = 0)
plt.scatter(fentanyl15192019['density'],fentanyl15192019['rate'])
plt.title("fentanyl 15-19 rate 2019")
plt.xlabel("Population Density")
plt.ylabel("rate")
# Out:
# Text(0, 0.5, 'rate')

# %%
fentanyl15192019 = fentanyl15192019[fentanyl15192019.apply(filter_deaths, axis=1)]
plt.scatter(fentanyl15192019['density'],fentanyl15192019['deaths'])
plt.title("fentanyl 15-19 death 2019")
# Out:
# Text(0.5, 1.0, 'fentanyl 15-19 death 2019')

# %%
anyopioid15192019 = pd.read_csv("15to19anyopioid2019.csv")
anyopioid15192019['county'] = anyopioid15192019['county'] + " County"
anyopioid15192019 = pd.merge(population2019, anyopioid15192019)
anyopioid15192019 = anyopioid15192019.drop(56, axis = 0)
plt.scatter(anyopioid15192019['density'],anyopioid15192019['rate'])
plt.title("any opioid 15-19 rate 2019")
plt.xlabel("Population Density")
plt.ylabel("rate")
# Out:
# Text(0, 0.5, 'rate')

# %%
anyopioid15192019 = anyopioid15192019[anyopioid15192019.apply(filter_deaths, axis=1)]
plt.scatter(anyopioid15192019['density'],anyopioid15192019['deaths'])
plt.title("any opioid 15-19 death 2019")
# Out:
# Text(0.5, 1.0, 'any opioid 15-19 death 2019')

# %%
anyopioid15192020 = pd.read_csv("15to19anyopioid2020.csv")
anyopioid15192020['county'] = anyopioid15192020['county'] + " County"
anyopioid15192020 = pd.merge(population2020, anyopioid15192020)
anyopioid15192020 = anyopioid15192020.drop(56, axis = 0)
plt.scatter(anyopioid15192020['density'],anyopioid15192020['rate'])
plt.title("any opioid 15-19 rate 2020")
plt.xlabel("Population Density")
plt.ylabel("rate")
# Out:
# Text(0, 0.5, 'rate')

# %%
anyopioid15192020 = anyopioid15192020[anyopioid15192020.apply(filter_deaths, axis=1)]
plt.scatter(anyopioid15192020['density'],anyopioid15192020['deaths'])
plt.title("any opioid 15-19 death 2020")
# Out:
# Text(0.5, 1.0, 'any opioid 15-19 death 2020')

# %%
anyopioid20242020 = pd.read_csv("20to24anyopioid2020.csv")
anyopioid20242020['county'] = anyopioid20242020['county'] + " County"
anyopioid20242020 = pd.merge(population2020, anyopioid20242020)
anyopioid20242020 = anyopioid20242020.drop(56, axis = 0)
plt.scatter(anyopioid20242020['density'],anyopioid20242020['rate'])
plt.title("any opioid 20-24 rate 2020")
plt.xlabel("Population Density")
plt.ylabel("rate")
# Out:
# Text(0, 0.5, 'rate')

# %%
anyopioid20242020 = anyopioid20242020[anyopioid20242020.apply(filter_deaths, axis=1)]
plt.scatter(anyopioid20242020['density'],anyopioid20242020['deaths'])
plt.title("any opioid 20-24 death 2020")
# Out:
# Text(0.5, 1.0, 'any opioid 20-24 death 2020')

# %%
anyopioid20242019 = pd.read_csv("20to24anyopioid2019.csv")
anyopioid20242019['county'] = anyopioid20242019['county'] + " County"
anyopioid20242019 = pd.merge(population2019, anyopioid20242019)
anyopioid20242019 = anyopioid20242019.drop(56, axis = 0)
plt.scatter(anyopioid20242019['density'],anyopioid20242019['rate'])
plt.title("any opioid 20-24 rate 2019")
plt.xlabel("Population Density")
plt.ylabel("rate")
# Out:
# Text(0, 0.5, 'rate')

# %%
anyopioid20242019 = anyopioid20242019[anyopioid20242019.apply(filter_deaths, axis=1)]
plt.scatter(anyopioid20242019['density'],anyopioid20242019['deaths'])
plt.title("any opioid 20-24 death 2019")
# Out:
# Text(0.5, 1.0, 'any opioid 20-24 death 2019')

# %%
anyopioid20242021 = pd.read_csv("20to24anyopioid2021.csv")
anyopioid20242021['county'] = anyopioid20242021['county'] + " County"
anyopioid20242021 = pd.merge(population2020, anyopioid20242021)
anyopioid20242021 = anyopioid20242021.drop(56, axis = 0)
plt.scatter(anyopioid20242021['density'],anyopioid20242021['rate'])
plt.title("any opioid 20-24 rate 2021")
plt.xlabel("Population Density")
plt.ylabel("rate")
# Out:
# Text(0, 0.5, 'rate')

# %%
anyopioid20242021 = anyopioid20242021[anyopioid20242021.apply(filter_deaths, axis=1)]
plt.scatter(anyopioid20242021['density'],anyopioid20242021['deaths'])
plt.title("any opioid 20-24 death 2021")
# Out:
# Text(0.5, 1.0, 'any opioid 20-24 death 2021')

# %%
fentanyl20242021 = pd.read_csv("20to24fentanyl2021.csv")
fentanyl20242021['county'] = fentanyl20242021['county'] + " County"
fentanyl20242021 = pd.merge(populations,fentanyl20242021)
fentanyl20242021 = fentanyl20242021.drop(56, axis = 0)
plt.scatter(fentanyl20242021['density'],fentanyl20242021['rate'])
plt.title("fentanyl 20-24 rate 2021")
plt.xlabel("Population Density")
plt.ylabel("rate")
# Out:
# Text(0, 0.5, 'rate')

# %%
fentanyl20242021 = fentanyl20242021[fentanyl20242021.apply(filter_deaths, axis=1)]
plt.scatter(fentanyl20242021['density'],fentanyl20242021['deaths'])
plt.title("fentanyl 20-24 death 2021")
# Out:
# Text(0.5, 1.0, 'fentanyl 20-24 death 2021')

# %%
fentanyl20242020 = pd.read_csv("20to24fentanyl2020.csv")
fentanyl20242020['county'] = fentanyl20242020['county'] + " County"
fentanyl20242020 = pd.merge(population2020,fentanyl20242020)
fentanyl20242020 = fentanyl20242020.drop(56, axis = 0)
plt.scatter(fentanyl20242020['density'],fentanyl20242020['rate'])
plt.title("fentanyl 20-24 rate 2020")
plt.xlabel("Population Density")
plt.ylabel("rate")
# Out:
# Text(0, 0.5, 'rate')

# %% [markdown]
# fentanyl20242020 = fentanyl20242020[fentanyl20242020.apply(filter_deaths, axis=1)]
# plt.scatter(fentanyl20242020['density'],fentanyl20242020['deaths'])
# plt.title("fentanyl 20-24 death 2021")

# %%
fentanyl20242020 = fentanyl20242020[fentanyl20242020.apply(filter_deaths, axis=1)]
plt.scatter(fentanyl20242020['density'],fentanyl20242020['deaths'])
plt.title("fentanyl 20-24 death 2021")
# Out:
# Text(0.5, 1.0, 'fentanyl 20-24 death 2021')

# %%
fentanyl20242019 = pd.read_csv("20to24fentanyl2019.csv")
fentanyl20242019['county'] = fentanyl20242019['county'] + " County"
fentanyl20242019 = pd.merge(population2019,fentanyl20242019)
fentanyl20242019 = fentanyl20242019.drop(56, axis = 0)
plt.scatter(fentanyl20242019['density'],fentanyl20242019['rate'])
plt.title("fentanyl 20-24 rate 2019")
plt.xlabel("Population Density")
plt.ylabel("Crude Rate")
# Out:
# Text(0, 0.5, 'Crude Rate')

# %%
fentanyl20242019['deaths2']=fentanyl20242019.apply(lambda x : int(x['deaths']),axis=1)

# %%
fentanyl20242019['deaths']=fentanyl20242019['deaths2']

# %%
fentanyl20242020['deaths2']=fentanyl20242020.apply(lambda x : int(x['deaths']),axis=1)

# %%
fentanyl20242020['deaths']=fentanyl20242020['deaths2']

# %%
fentanyl20242021['deaths2']=fentanyl20242021.apply(lambda x : int(x['deaths']),axis=1)

# %%
fentanyl20242021['deaths']=fentanyl20242021['deaths2']

# %%
plt.scatter(fentanyl20242019['density'],fentanyl20242019['deaths'], s=100, color='tab:red')

plt.scatter(fentanyl20242020['density'],fentanyl20242020['deaths'], s=100, color='tab:green')

plt.scatter(fentanyl20242021['density'],fentanyl20242021['deaths'], s=100, color='tab:blue')
plt.title("fentanyl 20-24 death 2019")
plt.xlabel("Density")
plt.ylabel("Deaths")
plt.title("Fentanyl 2024 Population Density vs. Clean Deaths")
plt.legend(['2019','2020', '2021'])

# %%
plt.scatter(fentanyl20242021['density'],fentanyl20242021['rate'], color = 'tab:blue')
plt.scatter(fentanyl20242020['density'],fentanyl20242020['rate'], color = 'tab:green')
plt.scatter(fentanyl20242019['density'],fentanyl20242019['rate'], color = 'tab:red')
plt.legend(['2021','2020','2019'])
plt.xlabel("Population Density")
plt.ylabel("Crude Rate")
plt.title("Ages 20-24 Fentanyl Population Density vs Crude Rates")
# Out:
# Text(0.5, 1.0, 'Ages 20-24 Fentanyl Population Density vs Crude Rates')

# %%
plt.scatter(anyopioid20242021['density'],anyopioid20242021['rate'], color = 'tab:blue')
plt.scatter(anyopioid20242020['density'],anyopioid20242020['rate'], color = 'tab:green')
plt.scatter(anyopioid20242019['density'],anyopioid20242019['rate'], color = 'tab:red')
plt.legend(['2021','2020','2019'])
plt.xlabel("Population Density")
plt.ylabel("Crude Rate")
plt.title("Ages 20-24 any opioid Population Density vs Crude Rates")
# Out:
# Text(0.5, 1.0, 'Ages 20-24 any opioid Population Density vs Crude Rates')

# %%
anyopioid20242019['deaths2']=anyopioid20242019.apply(lambda x : int(x['deaths']),axis=1)
anyopioid20242020['deaths2']=anyopioid20242020.apply(lambda x : int(x['deaths']),axis=1)
anyopioid20242021['deaths2']=anyopioid20242020.apply(lambda x : int(x['deaths']),axis=1)

# %%
plt.scatter(anyopioid20242021['density'], anyopioid20242021['deaths2'], color = 'tab:blue')
plt.scatter(anyopioid20242020['density'],anyopioid20242020['deaths2'], color = 'tab:green')
plt.scatter(anyopioid20242019['density'],anyopioid20242019['deaths2'], color = 'tab:red')
plt.legend(['2021','2020','2019'])
plt.xlabel("Population Density")
plt.ylabel("Deaths")
plt.title("Ages 20-24 Any Opioid Population Density vs Deaths")
# Out:
# Text(0.5, 1.0, 'Ages 20-24 Any Opioid Population Density vs Deaths')

# %%
plt.scatter(fentanyl15192021['density'],fentanyl15192021['rate'], color = 'tab:blue')
plt.scatter(fentanyl15192020['density'],fentanyl15192020['rate'], color = 'tab:green')
plt.scatter(fentanyl15192019['density'],fentanyl15192019['rate'], color = 'tab:red')
plt.legend(['2021','2020','2019'])
plt.xlabel("Population Density")
plt.ylabel("Crude Rate")
plt.title("Ages 15-19 Fentanyl Population Density vs Crude Rates")
# Out:
# Text(0.5, 1.0, 'Ages 15-19 Fentanyl Population Density vs Crude Rates')

# %%
populationsopioid15192021a = populationsopioid15192021.drop(56, axis = 0)

# %%
plt.scatter(populationsopioid15192021a['density'],populationsopioid15192021a['rate'], color = 'tab:blue')
plt.scatter(anyopioid15192020['density'],anyopioid15192020['rate'], color = 'tab:green')
plt.scatter(anyopioid15192019['density'],anyopioid15192019['rate'], color = 'tab:red')
plt.legend(['2021','2020','2019'])
plt.xlabel("Population Density")
plt.ylabel("Crude Rate")
plt.title("Ages 15-19 Any Opioid Population Density vs Crude Rates")
# Out:
# Text(0.5, 1.0, 'Ages 15-19 Any Opioid Population Density vs Crude Rates')

# %%
floatdeaths = [str(anyopioid15192020['deaths']) for line in anyopioid15192020['deaths']]

# %%
plt.scatter(anyopioid15192020['density'],anyopioid15192020['deaths'])

# %%
anyopioid15192021 = populationsopioid15192021a[populationsopioid15192021a.apply(filter_deaths, axis=1)]

# %%
anyopioid15192019['deaths2']=anyopioid15192019.apply(lambda x : int(x['deaths']),axis=1)
anyopioid15192020['deaths2']=anyopioid15192020.apply(lambda x : int(x['deaths']),axis=1)
anyopioid15192021['deaths2']=anyopioid15192021.apply(lambda x : int(x['deaths']),axis=1)
# Out:
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_24886/3977418845.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anyopioid15192021['deaths2']=anyopioid15192021.apply(lambda x : int(x['deaths']),axis=1)

# %%
plt.scatter(anyopioid15192021['density'],anyopioid15192021['deaths2'], color = 'tab:blue')
plt.scatter(anyopioid15192020['density'],anyopioid15192020['deaths2'], color = 'tab:green')
plt.scatter(anyopioid15192019['density'],anyopioid15192019['deaths2'], color = 'tab:red')
plt.legend(['2021','2020','2019'])
plt.xlabel("Population Density")
plt.ylabel("Deaths")
plt.title("Ages 15-19 Any Opioid Population Density vs Deaths")
# Out:
# Text(0.5, 1.0, 'Ages 15-19 Any Opioid Population Density vs Deaths')

# %%
fentanyl15192021 = fentanyl15192021[fentanyl15192021.apply(filter_deaths, axis=1)]
fentanyl15192020 = fentanyl15192020[fentanyl15192020.apply(filter_deaths, axis=1)]
fentanyl15192019 = fentanyl15192019[fentanyl15192019.apply(filter_deaths, axis=1)]

# %%
fentanyl15192019['deaths2']=fentanyl15192019.apply(lambda x : int(x['deaths']),axis=1)
fentanyl15192020['deaths2']=fentanyl15192020.apply(lambda x : int(x['deaths']),axis=1)
fentanyl15192021['deaths2']=fentanyl15192021.apply(lambda x : int(x['deaths']),axis=1)

# %%
plt.scatter(fentanyl15192021['density'],fentanyl15192021['deaths2'], color = 'tab:blue')
plt.scatter(fentanyl15192020['density'],fentanyl15192020['deaths2'], color = 'tab:green')
plt.scatter(fentanyl15192019['density'],fentanyl15192019['deaths2'], color = 'tab:red')
plt.legend(['2021','2020','2019'])
plt.xlabel("Population Density")
plt.ylabel("Deaths")
plt.title("Ages 15-19 Any Fentanyl Population Density vs Deaths")
# Out:
# Text(0.5, 1.0, 'Ages 15-19 Any Fentanyl Population Density vs Deaths')
