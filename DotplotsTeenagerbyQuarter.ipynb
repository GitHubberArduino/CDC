# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
teenager_anyopioid_quarters = pd.read_csv("TeenagerAnyOpioidbyquarter.csv")

# %%
teenager_anyopioid_quarters
# Out:
#        year   rate
# 0   2022.00   5.15
# 1   2021.75   5.35
# 2   2021.50   7.81
# 3   2021.25  12.29
# 4   2021.00   8.68
# 5   2020.75   7.89
# 6   2020.50  10.89
# 7   2020.25  13.89
# 8   2020.00   8.68
# 9   2019.75   6.00
# 10  2019.50   4.58
# 11  2019.25   2.53
# 12  2019.00   1.74

# %%
plt.rcParams["figure.figsize"] = (20,10)

# %%
plt.plot(teenager_anyopioid_quarters.year, teenager_anyopioid_quarters.rate)
plt.title("Crude Rate Per 100K of Any Opioid Overdose Date Rates for Teenagers by Quarter Years")
plt.xlabel("year")
plt.ylabel("Crude Rate Per 100K")
# Out:
# Text(0, 0.5, 'Crude Rate Per 100K')
