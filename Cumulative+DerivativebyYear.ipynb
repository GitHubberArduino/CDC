# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sympy import *

# %%
df = pd.read_csv('Counties2020.csv')

# %%
df["New"] = int('0')

# %%
df.sort_values(by = ['rate'], ascending= [True])
# Out:
#              county     rate     num1      num2    num3  New
# 58          Trinity   0.0000   0.0000   30.1700  0.0000    0
# 54           Alpine   0.0000   0.0000  329.9500  0.0000    0
# 57           Sierra   0.0000   0.0000  121.9900  0.0000    0
# 56             Mono   0.0000   0.0000   25.5600  0.0000    0
# 55            Modoc   0.0000   0.0000   41.6800  0.0000    0
# 53           Tehama   3.0450   0.8300   10.6100  1.5250    0
# 52    Santa Barbara   3.5700   2.1100    5.7375  0.8575    0
# 51         Tuolumne   3.6800   1.5875   12.3425  1.3000    0
# 50        Calaveras   4.3575   1.8800   14.6050  1.5400    0
# 49           Madera   4.4100   1.8075    9.0700  1.6500    0
# 48             Yolo   4.5100   2.3100    8.1700  1.3500    0
# 47           Plumas   5.2650   1.4350   28.0425  2.6325    0
# 46         Monterey   5.7375   3.7150    8.4625  1.1425    0
# 45         Mariposa   5.8100   1.5825   30.9575  2.9050    0
# 44             Napa   5.8275   2.8900   11.1775  1.7750    0
# 43       San Benito   6.2500   1.7000   16.0000  3.1200    0
# 42            Kings   6.4475   3.2575   11.7075  1.9525    0
# 41       Sacramento   6.8225   5.6100    8.2275  0.6500    0
# 40           Fresno   7.0375   5.5050    8.8750  0.8325    0
# 39      Santa Clara   7.4100   6.2475    8.7200  0.6175    0
# 38           Tulare   8.2875   5.9425   11.2850  1.3000    0
# 37          Alameda   8.5625   7.2250   10.0800  0.7100    0
# 36           Solano   8.6500   6.2250   11.7525  1.3475    0
# 35       Santa Cruz   9.5275   6.2550   13.9325  1.8550    0
# 34           Amador   9.9675   3.5100   24.8750  4.2525    0
# 33           Merced  10.2950   7.0350   14.6625  1.8450    0
# 32            Glenn  10.4900   3.9725   29.1825  4.2200    0
# 31        San Mateo  10.5400   8.3800   13.0925  1.1675    0
# 30        Del Norte  10.7250   4.0625   29.8400  4.3150    0
# 29      San Joaquin  10.9975   8.8125   13.5700  1.1775    0
# 28           Sutter  11.1075   6.2125   19.3075  2.8800    0
# 27           Placer  11.1325   8.1275   14.8875  1.6525    0
# 26        El Dorado  11.2475   7.1700   16.9125  2.3350    0
# 25             Yuba  11.2550   5.8775   20.7550  3.2175    0
# 24            Butte  11.7800   7.7800   17.1700  2.2650    0
# 23     Contra Costa  12.4225  10.4800   14.6200  1.0325    0
# 22            Marin  12.7875   8.8375   17.9300  2.2100    0
# 21      Los Angeles  12.9725  12.2775   13.6925  0.3600    0
# 20   San Bernardino  13.0875  11.6250   14.6875  0.7700    0
# 19       Stanislaus  13.3200  10.5100   16.6675  1.5200    0
# 18           Colusa  13.8150   3.7650   39.6250  6.9075    0
# 17       California  13.8725  13.5075   14.2425  0.1865    0
# 16           Shasta  14.9400  10.0325   21.5625  2.7825    0
# 15        San Diego  15.7700  14.4575   17.1650  0.6825    0
# 14           Orange  15.7950  14.4550   17.2275  0.7000    0
# 13        Riverside  16.0350  14.5000   17.6775  0.8000    0
# 12         Siskiyou  16.0850   7.8650   31.9875  5.0725    0
# 11             Inyo  16.5900   4.5225   47.5875  8.2950    0
# 10          Ventura  16.6875  14.0950   19.6400  1.3825    0
# 9          Imperial  17.5000  12.1150   24.5600  3.0200    0
# 8          Humboldt  17.8000  11.4525   26.4325  3.6050    0
# 7   San Luis Obispo  20.1300  15.2750   26.0575  2.6550    0
# 6            Sonoma  22.5250  18.5575   27.1025  2.1250    0
# 5            Lassen  22.7100  10.0725   45.9875  8.1125    0
# 4         Mendocino  23.0650  14.3325   35.4025  5.0350    0
# 3              Kern  24.4100  21.3150   27.8300  1.6325    0
# 2              Lake  26.3525  15.6375   41.9325  6.2450    0
# 1            Nevada  30.0600  20.3600   42.8350  5.4475    0
# 0     San Francisco  50.4500  45.8900   55.3425  2.3825    0
# 59          Unknown      NaN   0.0000       NaN     NaN    0

# %%
for county in df:
    df["New"] =  abs(df.index - 58)+1
df
# Out:
#              county     rate     num1      num2    num3  New
# 0     San Francisco  50.4500  45.8900   55.3425  2.3825   59
# 1            Nevada  30.0600  20.3600   42.8350  5.4475   58
# 2              Lake  26.3525  15.6375   41.9325  6.2450   57
# 3              Kern  24.4100  21.3150   27.8300  1.6325   56
# 4         Mendocino  23.0650  14.3325   35.4025  5.0350   55
# 5            Lassen  22.7100  10.0725   45.9875  8.1125   54
# 6            Sonoma  22.5250  18.5575   27.1025  2.1250   53
# 7   San Luis Obispo  20.1300  15.2750   26.0575  2.6550   52
# 8          Humboldt  17.8000  11.4525   26.4325  3.6050   51
# 9          Imperial  17.5000  12.1150   24.5600  3.0200   50
# 10          Ventura  16.6875  14.0950   19.6400  1.3825   49
# 11             Inyo  16.5900   4.5225   47.5875  8.2950   48
# 12         Siskiyou  16.0850   7.8650   31.9875  5.0725   47
# 13        Riverside  16.0350  14.5000   17.6775  0.8000   46
# 14           Orange  15.7950  14.4550   17.2275  0.7000   45
# 15        San Diego  15.7700  14.4575   17.1650  0.6825   44
# 16           Shasta  14.9400  10.0325   21.5625  2.7825   43
# 17       California  13.8725  13.5075   14.2425  0.1865   42
# 18           Colusa  13.8150   3.7650   39.6250  6.9075   41
# 19       Stanislaus  13.3200  10.5100   16.6675  1.5200   40
# 20   San Bernardino  13.0875  11.6250   14.6875  0.7700   39
# 21      Los Angeles  12.9725  12.2775   13.6925  0.3600   38
# 22            Marin  12.7875   8.8375   17.9300  2.2100   37
# 23     Contra Costa  12.4225  10.4800   14.6200  1.0325   36
# 24            Butte  11.7800   7.7800   17.1700  2.2650   35
# 25             Yuba  11.2550   5.8775   20.7550  3.2175   34
# 26        El Dorado  11.2475   7.1700   16.9125  2.3350   33
# 27           Placer  11.1325   8.1275   14.8875  1.6525   32
# 28           Sutter  11.1075   6.2125   19.3075  2.8800   31
# 29      San Joaquin  10.9975   8.8125   13.5700  1.1775   30
# 30        Del Norte  10.7250   4.0625   29.8400  4.3150   29
# 31        San Mateo  10.5400   8.3800   13.0925  1.1675   28
# 32            Glenn  10.4900   3.9725   29.1825  4.2200   27
# 33           Merced  10.2950   7.0350   14.6625  1.8450   26
# 34           Amador   9.9675   3.5100   24.8750  4.2525   25
# 35       Santa Cruz   9.5275   6.2550   13.9325  1.8550   24
# 36           Solano   8.6500   6.2250   11.7525  1.3475   23
# 37          Alameda   8.5625   7.2250   10.0800  0.7100   22
# 38           Tulare   8.2875   5.9425   11.2850  1.3000   21
# 39      Santa Clara   7.4100   6.2475    8.7200  0.6175   20
# 40           Fresno   7.0375   5.5050    8.8750  0.8325   19
# 41       Sacramento   6.8225   5.6100    8.2275  0.6500   18
# 42            Kings   6.4475   3.2575   11.7075  1.9525   17
# 43       San Benito   6.2500   1.7000   16.0000  3.1200   16
# 44             Napa   5.8275   2.8900   11.1775  1.7750   15
# 45         Mariposa   5.8100   1.5825   30.9575  2.9050   14
# 46         Monterey   5.7375   3.7150    8.4625  1.1425   13
# 47           Plumas   5.2650   1.4350   28.0425  2.6325   12
# 48             Yolo   4.5100   2.3100    8.1700  1.3500   11
# 49           Madera   4.4100   1.8075    9.0700  1.6500   10
# 50        Calaveras   4.3575   1.8800   14.6050  1.5400    9
# 51         Tuolumne   3.6800   1.5875   12.3425  1.3000    8
# 52    Santa Barbara   3.5700   2.1100    5.7375  0.8575    7
# 53           Tehama   3.0450   0.8300   10.6100  1.5250    6
# 54           Alpine   0.0000   0.0000  329.9500  0.0000    5
# 55            Modoc   0.0000   0.0000   41.6800  0.0000    4
# 56             Mono   0.0000   0.0000   25.5600  0.0000    3
# 57           Sierra   0.0000   0.0000  121.9900  0.0000    2
# 58          Trinity   0.0000   0.0000   30.1700  0.0000    1
# 59          Unknown      NaN   0.0000       NaN     NaN    2

# %%
plt.plot(df['rate'],df['New']) 
plt.xlabel("Rate of Counties") 
plt.ylabel("Number of Counties")
# Out:
# Text(0, 0.5, 'Number of Counties')

# %%
def ratelessthan1(row):
    if row['rate'] < 1:
        return False
    else:
        return True

# %%
len(df[df['rate']<10])
df2 = pd.DataFrame(columns=['rate', 'ccount'])

for key in range(100):
    df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# Out:
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_79784/2602404310.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)

# %%
plt.plot(df2['rate'],df2['ccount']) 
plt.xlabel("Rate of Counties") 
plt.ylabel("Cumulative Percentage of Counties")
# Out:
# Text(0, 0.5, 'Cumulative Percentage of Counties')

# %%
import lmfit

model = lmfit.models.ExpressionModel("x^b/(x^b+d)")
params = model.make_params(b=1.222, d=3.333)
fit = model.fit(df2['ccount'], params, x= df2['rate'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/asteval/asteval.py:301, in Interpreter.run(self, node, expr, lineno, with_raise)
#     300 try:
# --> 301     ret = handler(node)
#     302     if isinstance(ret, enumerate):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/asteval/asteval.py:584, in Interpreter.on_binop(self, node)
#     583 """Binary operator."""
# --> 584 return op2func(node.op)(self.run(node.left),
#     585                         self.run(node.right))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/asteval/astutils.py:232, in <lambda>(a, b)
#     222     return a << b
#     225 OPERATORS = {ast.Is: lambda a, b: a is b,
#     226              ast.IsNot: lambda a, b: a is not b,
#     227              ast.In: lambda a, b: a in b,
#     228              ast.NotIn: lambda a, b: a not in b,
#     229              ast.Add: safe_add,
#     230              ast.BitAnd: lambda a, b: a & b,
#     231              ast.BitOr: lambda a, b: a | b,
# --> 232              ast.BitXor: lambda a, b: a ^ b,
#     233              ast.Div: lambda a, b: a / b,
#     234              ast.FloorDiv: lambda a, b: a // b,
#     235              ast.LShift: safe_lshift,
#     236              ast.RShift: lambda a, b: a >> b,
#     237              ast.Mult: safe_mult,
#     238              ast.Pow: safe_pow,
#     239              ast.Sub: lambda a, b: a - b,
#     240              ast.Mod: lambda a, b: a % b,
#     241              ast.And: lambda a, b: a and b,
#     242              ast.Or: lambda a, b: a or b,
#     243              ast.Eq: lambda a, b: a == b,
#     244              ast.Gt: lambda a, b: a > b,
#     245              ast.GtE: lambda a, b: a >= b,
#     246              ast.Lt: lambda a, b: a < b,
#     247              ast.LtE: lambda a, b: a <= b,
#     248              ast.NotEq: lambda a, b: a != b,
#     249              ast.Invert: lambda a: ~a,
#     250              ast.Not: lambda a: not a,
#     251              ast.UAdd: lambda a: +a,
#     252              ast.USub: lambda a: -a}
#     255 def valid_symbol_name(name):
#
# TypeError: ufunc 'bitwise_xor' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 5>()
#       3 model = lmfit.models.ExpressionModel("x^b/(x^b+d)")
#       4 params = model.make_params(b=1.222, d=3.333)
# ----> 5 fit = model.fit(df2['ccount'], params, x= df2['rate'])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/lmfit/model.py:1050, in Model.fit(self, data, params, weights, method, iter_cb, scale_covar, verbose, fit_kws, nan_policy, calc_covar, max_nfev, **kwargs)
#    1044     fit_kws = {}
#    1046 output = ModelResult(self, params, method=method, iter_cb=iter_cb,
#    1047                      scale_covar=scale_covar, fcn_kws=kwargs,
#    1048                      nan_policy=self.nan_policy, calc_covar=calc_covar,
#    1049                      max_nfev=max_nfev, **fit_kws)
# -> 1050 output.fit(data=data, weights=weights)
#    1051 output.components = self.components
#    1052 return output
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/lmfit/model.py:1404, in ModelResult.fit(self, data, params, weights, method, nan_policy, **kwargs)
#    1402 self.userargs = (self.data, self.weights)
#    1403 self.userkws.update(kwargs)
# -> 1404 self.init_fit = self.model.eval(params=self.params, **self.userkws)
#    1405 _ret = self.minimize(method=self.method)
#    1407 for attr in dir(_ret):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/lmfit/model.py:868, in Model.eval(self, params, **kwargs)
#     836 def eval(self, params=None, **kwargs):
#     837     """Evaluate the model with supplied parameters and keyword arguments.
#     838
#     839     Parameters
#    (...)
#     866
#     867     """
# --> 868     return self.func(**self.make_funcargs(params, kwargs))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/lmfit/models.py:1496, in ExpressionModel.__init__.<locals>._eval(**kwargs)
#    1494     self.asteval.symtable[name] = val
#    1495 self.asteval.start_time = time.time()
# -> 1496 return self.asteval.run(self.astcode)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/asteval/asteval.py:301, in Interpreter.run(self, node, expr, lineno, with_raise)
#     298 # run the handler:  this will likely generate
#     299 # recursive calls into this run method.
#     300 try:
# --> 301     ret = handler(node)
#     302     if isinstance(ret, enumerate):
#     303         ret = list(ret)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/asteval/asteval.py:391, in Interpreter.on_module(self, node)
#     389 out = None
#     390 for tnode in node.body:
# --> 391     out = self.run(tnode)
#     392 return out
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/asteval/asteval.py:301, in Interpreter.run(self, node, expr, lineno, with_raise)
#     298 # run the handler:  this will likely generate
#     299 # recursive calls into this run method.
#     300 try:
# --> 301     ret = handler(node)
#     302     if isinstance(ret, enumerate):
#     303         ret = list(ret)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/asteval/asteval.py:368, in Interpreter.on_expr(self, node)
#     366 def on_expr(self, node):
#     367     """Expression."""
# --> 368     return self.run(node.value)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/asteval/asteval.py:301, in Interpreter.run(self, node, expr, lineno, with_raise)
#     298 # run the handler:  this will likely generate
#     299 # recursive calls into this run method.
#     300 try:
# --> 301     ret = handler(node)
#     302     if isinstance(ret, enumerate):
#     303         ret = list(ret)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/asteval/asteval.py:585, in Interpreter.on_binop(self, node)
#     582 def on_binop(self, node):    # ('left', 'op', 'right')
#     583     """Binary operator."""
#     584     return op2func(node.op)(self.run(node.left),
# --> 585                             self.run(node.right))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/asteval/asteval.py:301, in Interpreter.run(self, node, expr, lineno, with_raise)
#     298 # run the handler:  this will likely generate
#     299 # recursive calls into this run method.
#     300 try:
# --> 301     ret = handler(node)
#     302     if isinstance(ret, enumerate):
#     303         ret = list(ret)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/asteval/asteval.py:585, in Interpreter.on_binop(self, node)
#     582 def on_binop(self, node):    # ('left', 'op', 'right')
#     583     """Binary operator."""
#     584     return op2func(node.op)(self.run(node.left),
# --> 585                             self.run(node.right))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/asteval/asteval.py:309, in Interpreter.run(self, node, expr, lineno, with_raise)
#     306 if with_raise:
#     307     if len(self.error) == 0:
#     308         # Unhandled exception that didn't use raise_exception
# --> 309         self.raise_exception(node, expr=expr)
#     310     raise
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/asteval/asteval.py:249, in Interpreter.raise_exception(self, node, exc, msg, expr, lineno)
#     247     except:
#     248         exc = RuntimeError
# --> 249 raise exc(self.error_msg)
#
# TypeError: at expr='x^b/(x^b+d)'

# %%
class DecayingSineModel(lmfit.Model):
    def __init__(self, *args, **kwargs):
        def decaying_sine(x,b,d):
            return pow(x,b)/(pow(x,b)+d)
        super(DecayingSineModel, self).__init__(decaying_sine, *args, **kwargs)

    def guess(self, data, **kwargs):
        params = self.make_params(b=1.22, d= 3.33)
        return lmfit.models.update_param_vals(params, self.prefix, **kwargs)

# %%
model = DecayingSineModel()
params = model.guess(df2['ccount'], x=df2['rate'])
fit = model.fit(df2['ccount'], params, x=df2['rate'])

# %%
fit.plot_fit()
# Out:
# <AxesSubplot:title={'center':'Model(decaying_sine)'}, xlabel='x', ylabel='y'>

# %%
fit
# Out:
# <h2> Model</h2> Model(decaying_sine) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>40</td><td></td></tr><tr><td># data points</td><td>100</td><td></td></tr><tr><td># variables</td><td>2</td><td></td></tr><tr><td>chi-square</td><td> 0.04305478</td><td></td></tr><tr><td>reduced chi-square</td><td> 4.3933e-04</td><td></td></tr><tr><td>Akaike info crit.</td><td>-771.045217</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-765.834877</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> b </td><td>  2.52309827 </td><td>  0.05246906 </td><td> (2.08%) </td><td> 1.22 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> d </td><td>  350.986978 </td><td>  47.3370340 </td><td> (13.49%) </td><td> 3.33 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>b</td><td>d</td><td>0.9837</td></tr></table>

# %%
b = 2.52309827
d = 350.986978

# %%
def prime3(row):
    x = row['rate']
    q = pow(x,b)
    return (d*b*pow(x,b-1))/(pow((q+d),2))
df2['derivative'] = df2.apply(prime3,axis=1)
df2
# Out:
#     rate    ccount  derivative
# 0    0.0  0.000000    0.000000
# 1    1.0  0.083333    0.007148
# 2    2.0  0.083333    0.020000
# 3    3.0  0.083333    0.035047
# 4    4.0  0.133333    0.049602
# ..   ...       ...         ...
# 95  95.0  0.983333    0.000095
# 96  96.0  0.983333    0.000091
# 97  97.0  0.983333    0.000088
# 98  98.0  0.983333    0.000085
# 99  99.0  0.983333    0.000082
#
# [100 rows x 3 columns]
