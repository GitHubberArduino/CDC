# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sympy import *
import lmfit
from lmfit import Parameters, minimize
from lmfit.printfuncs import report_fit

# %%
def ratelessthan1(row):
        if row['rate'] < 1:
            return False
        else:
            return True

# %%
class DecayingSineModel(lmfit.Model):
    def __init__(self, *args, **kwargs):
        def decaying_sine(x,b,d):
            return pow(x,b)/(pow(x,b)+d)
        super(DecayingSineModel, self).__init__(decaying_sine, *args, **kwargs)

    def guess(self, data, **kwargs):
        params = self.make_params(b= 1.22, d= 3.33)
        return lmfit.models.update_param_vals(params, self.prefix, **kwargs)

# %%
class DecayingSineModel2021(lmfit.Model):
    def __init__(self, *args, **kwargs):
        def decaying_sine2021(x,b,d):
            return pow(x,b)/(pow(x,b)+d)
        super(DecayingSineModel2021, self).__init__(decaying_sine2021, *args, **kwargs)

    def guess(self, data, **kwargs):
        #params = self.make_params(b= 1.22, d= 3.33)
        params = Parameters()
        params.add('b', value=1.1)
        params.add('d', value = 3.3, min= 80, max= 200)
        return lmfit.models.update_param_vals(params, self.prefix, **kwargs)

# %%
def getModel(year):
    df = pd.read_csv(year)
    df["New"]= int('0')
    df.sort_values(by = ['rate'], ascending= [True])
    for county in df:
        df["New"] =  abs(df.index - 58)+1
    df2 = pd.DataFrame(columns=['rate', 'ccount'])
    for key in range(100):
        df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
    print(df2)
    if year == '6064anyopioid2021.csv' or year == '30to44anyopioid2020.csv':  
        model = DecayingSineModel2021()
        params = model.guess(df2['ccount'], x=df2['rate'])
        fit = model.fit(df2['ccount'], params, x=df2['rate'] )
    else:
        model = DecayingSineModel()
        params = model.guess(df2['ccount'], x=df2['rate'])
        fit = model.fit(df2['ccount'], params, x=df2['rate'] )
    return fit, df2

# %%
df2021 = pd.read_csv('6064anyopioid2021.csv')
df2021
# Out:
#              county      rate     num1       num2      num3
# 0     San Francisco  113.7850  86.0925   147.6250  15.13500
# 1             Butte  110.3550  63.3325   182.4900  27.98500
# 2           Trinity   91.5750  24.9500   487.8250  45.78750
# 3            Colusa   76.6875  20.8950   408.5175  38.34250
# 4            Nevada   64.6250  21.7275   150.2125  28.52750
# 5          Siskiyou   61.2350  16.6850   213.2650  30.62000
# 6         Del Norte   55.7425  15.1875   296.9350  27.87000
# 7              Kern   51.4275  33.3050    76.1900  10.32000
# 8         Calaveras   49.4200  13.4650   172.1100  24.71000
# 9   San Luis Obispo   45.1700  20.7775    85.6325  14.99750
# 10         Humboldt   43.8375  15.4325   109.4150  18.71000
# 11           Sutter   35.8350   9.7650   124.8050  17.92000
# 12        Mendocino   33.4200   9.1050   116.4000  16.71000
# 13       Stanislaus   32.3550  16.0900    59.0075   9.94250
# 14            Marin   31.9375  15.0700    66.7475  10.64750
# 15            Kings   30.0525  12.9750   100.7875  10.62500
# 16        San Diego   29.7325  22.6575    38.3300   3.85750
# 17           Orange   28.3400  21.4775    36.7100   3.74750
# 18        Riverside   26.7450  19.1575    36.4275   4.21250
# 19          Ventura   26.1300  15.1375    42.6425   6.48750
# 20       San Benito   25.8725   7.0500   137.8250  12.93750
# 21      San Joaquin   24.9150  12.9275    44.1425   7.26500
# 22           Tehama   23.5675   6.4225   125.5500  11.78500
# 23       California   22.4575  20.6050    24.4325   0.96525
# 24           Sonoma   21.6200   9.9850    42.0375   7.31250
# 25             Lake   21.1950   5.7750   112.9100  10.59750
# 26     Contra Costa   19.9725  11.6750    32.1975   4.86250
# 27        El Dorado   19.4775   7.3750    54.1875   7.83750
# 28    Santa Barbara   19.0625   7.9850    43.0125   7.11250
# 29           Placer   18.4225   7.7150    41.5675   6.87500
# 30       Sacramento   16.2925   9.2775    26.7250   4.12250
# 31      Los Angeles   14.4100  11.5800    17.7250   1.52250
# 32      Santa Clara   13.3475   7.7425    21.5700   3.28250
# 33   San Bernardino   12.9875   7.4900    21.0250   3.21250
# 34          Alameda   12.7825   7.3175    21.4075   3.29000
# 35         Monterey   12.5100   3.4050    35.8700   6.25500
# 36        San Mateo   11.6975   4.6125    25.1850   4.61250
# 37           Fresno   11.6300   4.4050    25.2050   4.68000
# 38       Santa Cruz   10.7750   2.9350    37.5300   5.39000
# 39         Imperial   10.2050   2.7800    54.3700   5.10250
# 40             Yolo    9.1050   2.4800    48.4950   4.55250
# 41           Shasta    8.4000   2.2875    44.7500   4.20000
# 42           Merced    7.3975   2.0150    39.4100   3.70000
# 43           Solano    6.8625   2.9625    23.0175   2.42750
# 44           Alpine    0.0000   0.0000  3293.6400   0.00000
# 45           Amador    0.0000   0.0000   117.2200   0.00000
# 46            Glenn    0.0000   0.0000   216.4800   0.00000
# 47             Inyo    0.0000   0.0000   214.2200   0.00000
# 48           Lassen    0.0000   0.0000   191.2300   0.00000
# 49           Madera    0.0000   0.0000    45.9900   0.00000
# 50         Mariposa    0.0000   0.0000   215.9800   0.00000
# 51            Modoc    0.0000   0.0000   549.7600   0.00000
# 52             Mono    0.0000   0.0000   301.8700   0.00000
# 53             Napa    0.0000   0.0000    38.6400   0.00000
# 54           Plumas    0.0000   0.0000   231.2800   0.00000
# 55           Sierra    0.0000   0.0000  1267.6600   0.00000
# 56           Tulare    0.0000   0.0000    16.0700   0.00000
# 57         Tuolumne    0.0000   0.0000    86.4500   0.00000
# 58             Yuba    0.0000   0.0000    83.6100   0.00000
# 59          Unknown       NaN   0.0000        NaN       NaN

# %%
f,df2= getModel('6064anyopioid2021.csv')
# Out:
#     rate  ccount
# 0    0.0    0.00
# 1    1.0    0.25
# 2    2.0    0.25
# 3    3.0    0.25
# 4    4.0    0.25
# ..   ...     ...
# 95  95.0    0.95
# 96  96.0    0.95
# 97  97.0    0.95
# 98  98.0    0.95
# 99  99.0    0.95
#
# [100 rows x 2 columns]
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)

# %%
x = df2['rate']
y= df2['ccount']
plt.plot(x,y)

# %%
f.params["b"].value,f.params["d"].value
# Out:
# (1.541910069746876, 92.24786745484838)

# %%
f,df2= getModel('6064anyopioid2020.csv')
# Out:
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
#     rate    ccount
# 0    0.0  0.000000
# 1    1.0  0.350000
# 2    2.0  0.350000
# 3    3.0  0.350000
# 4    4.0  0.350000
# ..   ...       ...
# 95  95.0  0.983333
# 96  96.0  0.983333
# 97  97.0  0.983333
# 98  98.0  0.983333
# 99  99.0  0.983333
#
# [100 rows x 2 columns]

# %%
f.params["b"].value,f.params["d"].value
# Out:
# (1.345678144283511, 18.012097813227474)

# %%
df2
# Out:
#     rate    ccount
# 0    0.0  0.000000
# 1    1.0  0.350000
# 2    2.0  0.350000
# 3    3.0  0.350000
# 4    4.0  0.350000
# ..   ...       ...
# 95  95.0  0.983333
# 96  96.0  0.983333
# 97  97.0  0.983333
# 98  98.0  0.983333
# 99  99.0  0.983333
#
# [100 rows x 2 columns]

# %%
x = df2['rate']
y= df2['ccount']
plt.plot(x,y)

# %%
files = ['6064anyopioid2021.csv', '6064anyopioid2020.csv','6064anyopioid2019.csv','6064anyopioid2018.csv','6064anyopioid2017.csv']
bval = []
dval = []
year = []
for file in files:
    f,df2 = getModel(file)
    year.append(file)
    bval.append(f.params["b"].value)
    dval.append(f.params["d"].value)
# Out:
#     rate  ccount
# 0    0.0    0.00
# 1    1.0    0.25
# 2    2.0    0.25
# 3    3.0    0.25
# 4    4.0    0.25
# ..   ...     ...
# 95  95.0    0.95
# 96  96.0    0.95
# 97  97.0    0.95
# 98  98.0    0.95
# 99  99.0    0.95
#
# [100 rows x 2 columns]
#     rate    ccount
# 0    0.0  0.000000
# 1    1.0  0.350000
# 2    2.0  0.350000
# 3    3.0  0.350000
# 4    4.0  0.350000
# ..   ...       ...
# 95  95.0  0.983333
# 96  96.0  0.983333
# 97  97.0  0.983333
# 98  98.0  0.983333
# 99  99.0  0.983333
#
# [100 rows x 2 columns]
#     rate    ccount
# 0    0.0  0.000000
# 1    1.0  0.383333
# 2    2.0  0.383333
# 3    3.0  0.400000
# 4    4.0  0.400000
# ..   ...       ...
# 95  95.0  0.983333
# 96  96.0  0.983333
# 97  97.0  0.983333
# 98  98.0  0.983333
# 99  99.0  0.983333
#
# [100 rows x 2 columns]
#     rate    ccount
# 0    0.0  0.000000
# 1    1.0  0.350000
# 2    2.0  0.350000
# 3    3.0  0.350000
# 4    4.0  0.383333
# ..   ...       ...
# 95  95.0  0.966667
# 96  96.0  0.966667
# 97  97.0  0.966667
# 98  98.0  0.966667
# 99  99.0  0.966667
#
# [100 rows x 2 columns]
#     rate    ccount
# 0    0.0  0.000000
# 1    1.0  0.316667
# 2    2.0  0.316667
# 3    3.0  0.333333
# 4    4.0  0.366667
# ..   ...       ...
# 95  95.0  0.966667
# 96  96.0  0.966667
# 97  97.0  0.966667
# 98  98.0  0.966667
# 99  99.0  0.966667
#
# [100 rows x 2 columns]
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_97164/1623195357.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({"rate": key, "ccount":len(df[df['rate']<key])/60},ignore_index = True)

# %%
bval
# Out:
# [1.541910069746876,
#  1.345678144283511,
#  1.1935730958303992,
#  1.2207535336442932,
#  1.203501950719296]

# %%
year
# Out:
# ['6064anyopioid2021.csv',
#  '6064anyopioid2020.csv',
#  '6064anyopioid2019.csv',
#  '6064anyopioid2018.csv',
#  '6064anyopioid2017.csv']

# %%
dval
# Out:
# [92.24786745484838,
#  18.012097813227474,
#  7.18591214784464,
#  9.237704320824664,
#  9.106130613830668]

# %%
year_no=0
density_x=[]
rate_y=[]
for x in range(60):
    b = bval[year_no]
    d = dval[year_no]
    q = pow(x,b)
    density_x.append(x)
    y_rate=d*b*pow(x,b-1)/(pow((q+d),2)) #derivativeofb&dequation
    rate_y.append(y_rate)

plt.plot(density_x,rate_y)

# %%
year_no=0
density_x=[]
rate_y=[]

for x in range(60):
    b = bval[year_no]
    d = dval[year_no]
    q = pow(x,b)
    density_x.append(x)
    y_rate=d*b*pow(x,b-1)/(pow((q+d),2))
    rate_y.append(y_rate)


plt.plot(density_x,rate_y)

# %%
x = [2021,2020,2019,2018,2017]
y = bval
plt.plot(x,y )

# %%
x = [2021,2020,2019,2018,2017]
y = dval
plt.plot(x,y )

# %%
def prime3(x,b,d):
    q = pow(x,b)
    return (d*b*pow(x,b-1))/(pow((q+d),2))

# %%
plt.rcParams["figure.figsize"] = (20,10)

# %%
bval_1 = bval[0:5]
bval_1 = dval[0:5]
year2= [2021,2020,2019,2018,2017]
for m in range(len(bval_1)):
    print(m)
    x = []
    y= []
    b = bval[m]
    d = dval[m]
    for i in range(60):
        x.append(i)
        y.append(prime3(x[i],b,d))
    plt.plot(x,y,label= str(year2[m]))
plt.legend(title='year')
plt.xlabel("Overdose Rates(Crude Rate for 100K)", fontsize = 20)
plt.ylabel("Probability based on number of counties", fontsize = 20)
plt.title("Density Curve: 60-64 Any Opioid Overdose Death Rates", fontsize = 20)
# Out:
# 0
# 1
# 2
# 3
# 4
# Text(0.5, 1.0, 'Density Curve: 60-64 Any Opioid Overdose Death Rates')

# %%
bval_2 = bval[4:]
dval_2 = dval[4:]
for m in range(len(bval_2)):
    x = []
    y= []
    b = bval_2[m]
    d = dval_2[m]
    for i in range(100):
        x.append(i)
        y.append(prime3(x[i],b,d))
        plt.plot(x,y,label= str(year2[m]))
    plt.plot(x,y)
plt.legend(["2018", "2017", "2016", "2015", "2014"])
# Out:
# /var/folders/h4/r6tpj_q56gb11bpc5pv3wfyr0000gn/T/ipykernel_89527/1062718043.py:3: RuntimeWarning: divide by zero encountered in double_scalars
#   return (d*b*pow(x,b-1))/(pow((q+d),2))

# %%
3#
